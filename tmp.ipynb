# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import requests
from sodapy import Socrata

pip install tensorflow numpy matplotlib sodapy pandas requests
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import requests

def send_message_to_telegram(message):
    chatId = '5303880405'
    botToken = '5660046213:AAHCSDYbdW7E5rc5MnoL1n8QCY-Qh8M1ZgI'
    url = f"https://api.telegram.org/bot{botToken}/sendMessage?chat_id={chatId}&text={message}"
    requests.get(url)

# %%
# client = Socrata("data.sonomacounty.ca.gov", None)

# results = client.get("924a-vesw", limit = 100000)

# df = pd.DataFrame.from_records(results)

# %%
df = pd.read_csv('dataset\Animal_Shelter_Intake_and_Outcome.csv', sep=';')
# df =  pandas.read_csv("https://data.sonomacounty.ca.gov/resource/924a-vesw.csv")

# %%
df
# Out:
#            Name   Type               Breed        Color       Sex   Size
# 0         RAZOR    DOG      BOSTON TERRIER  BLACK/WHITE  Neutered  SMALL  \
# 1           NaN    DOG   GERM SHEPHERD/MIX  BLACK/BROWN  Neutered    MED
# 2           NaN    DOG  SIBERIAN HUSKY/MIX          RED    Female    MED
# 3           NaN    DOG       GERM SHEPHERD  BLACK/BROWN  Neutered    MED
# 4         CHLOE    DOG      SIBERIAN HUSKY  BLACK/WHITE    Female  SMALL
# ...         ...    ...                 ...          ...       ...    ...
# 25430      BUBA    CAT         DOMESTIC SH   GRAY/WHITE  Neutered  SMALL
# 25431  *JESSICA  OTHER            AMERICAN  WHITE/BROWN    Spayed  SMALL
# 25432    SHINER    DOG            PIT BULL    TAN/WHITE  Neutered  LARGE
# 25433   *NEWTON    DOG    CHIHUAHUA SH/MIX  BROWN/WHITE  Neutered  SMALL
# 25434       NaN  OTHER               SHEEP        WHITE    Female  LARGE
#
#       Date Of Birth Impound Number Kennel Number Animal ID  ...
# 0        10/29/2009     K22-043412         TRUCK   A396382  ...  \
# 1               NaN     K23-044765          DS53   A417653  ...
# 2               NaN     K23-044764          DS49   A417654  ...
# 3               NaN     K23-044766          DS60   A417652  ...
# 4        05/18/2022     K23-044756          DS62   A417644  ...
# ...             ...            ...           ...       ...  ...
# 25430    10/15/2017     K19-033988          CA02   A392014  ...
# 25431    11/08/2017     K18-028720          CA01   A374156  ...
# 25432    12/22/2012     K14-010771          DS70   A293651  ...
# 25433    07/28/2011     K20-036116          DS91   A398415  ...
# 25434           NaN     K18-027518          YARD   A369354  ...
#
#          Intake Subtype     Outcome Type Outcome Subtype Intake Condition
# 0                 FIELD  RETURN TO OWNER       FLD_IDTAG          UNKNOWN  \
# 1      OVER THE COUNTER         TRANSFER          WONDER          UNKNOWN
# 2      OVER THE COUNTER         TRANSFER          WONDER          UNKNOWN
# 3      OVER THE COUNTER         TRANSFER          WONDER          UNKNOWN
# 4                 FIELD         TRANSFER          WONDER          UNKNOWN
# ...                 ...              ...             ...              ...
# 25430  OVER THE COUNTER         ADOPTION          WALKIN          HEALTHY
# 25431  OVER THE COUNTER         TRANSFER            HSSC          HEALTHY
# 25432  OVER THE COUNTER        EUTHANIZE      AGGRESSIVE      UNTREATABLE
# 25433             FIELD         TRANSFER      ROCKET DOG          HEALTHY
# 25434             FIELD  RETURN TO OWNER             NaN          UNKNOWN
#
#       Outcome Condition Intake Jurisdiction Outcome Jurisdiction
# 0               HEALTHY          SANTA ROSA           SANTA ROSA  \
# 1               HEALTHY              COUNTY               COUNTY
# 2               HEALTHY              COUNTY               COUNTY
# 3               HEALTHY              COUNTY               COUNTY
# 4               HEALTHY              COUNTY               COUNTY
# ...                 ...                 ...                  ...
# 25430           HEALTHY          SANTA ROSA          *HEALDSBURG
# 25431           HEALTHY          SANTA ROSA               COUNTY
# 25432       UNTREATABLE          SANTA ROSA               COUNTY
# 25433           HEALTHY          SANTA ROSA        OUT OF COUNTY
# 25434               NaN              COUNTY               COUNTY
#
#       Outcome Zip Code                     Location Count
# 0              95404.0  95404(38.43807, -122.71247)     1
# 1              94951.0  94951(38.29715, -122.66645)     1
# 2              94951.0  94951(38.29715, -122.66645)     1
# 3              94951.0  94951(38.29715, -122.66645)     1
# 4              94951.0  94951(38.29715, -122.66645)     1
# ...                ...                          ...   ...
# 25430          95448.0  95448(38.61064, -122.86883)     1
# 25431          95407.0  95407(38.41483, -122.72707)     1
# 25432          95476.0  95476(38.29188, -122.45728)     1
# 25433          94146.0                        94146     1
# 25434          95472.0  95472(38.40179, -122.82512)     1
#
# [25435 rows x 24 columns]

# %% [markdown]
# Name - Name of the animal. Animal names with an asterisk before them were given by shelter staff.<br>
# Type - Type of animal<br>
# Breed - Breed of animal<br>
# Color - Color of animal, Black, Chocolate, White….
# <br>Sex - Male, Female, Neutered Male, Spayed Female
# <br>Size - Large, medium, small, toy
# <br>Date Of Birth - Approximate date of birth.
# <br>Impound Number - Animal impound number
# <br>Kennel Number - Kennel number indicating its current location.
# <br>Animal ID - Unique ID
# <br>Intake Date	- Date animal was taken into the shelter
# <br>Outcome Date - Date animal left the shelter
# <br>Days in Shelter	- Number of days the animal was in the shelter
# <br>Intake Type	- Reason for intake
# <br>Intake Subtype - Sub reason for intake
# <br>Outcome Type - Reason for release from shelter
# <br>Outcome Subtype	- Sub reason for release from shelter
# <br>Intake Condition - Animals condition at intake
# <br>Outcome Condition - Animals condition at release from shelter
# <br>Intake Jurisdiction	- Jurisdiction responsible for animal intake
# <br>Outcome Jurisdiction - Area animal went to.
# <br>Outcome Zip Code - Zip code where animal went to.
# <br>Location - Latitude, Longitude coordinates for outcome jurisdiction
# <br>Count - Column for performing arithmetic and creating groups for views and visualizations

# %%
df.isnull().sum()
# Out:
# Name                    6670
# Type                       0
# Breed                      0
# Color                      0
# Sex                        0
# Size                      35
# Date Of Birth           6329
# Impound Number             0
# Kennel Number             30
# Animal ID                  0
# Intake Date                0
# Outcome Date             211
# Days in Shelter            0
# Intake Type                0
# Intake Subtype             0
# Outcome Type             217
# Outcome Subtype          537
# Intake Condition           0
# Outcome Condition        564
# Intake Jurisdiction        0
# Outcome Jurisdiction    3668
# Outcome Zip Code        3724
# Location                3724
# Count                      0
# dtype: int64

# %%
df = df.drop(['Impound Number', 'Animal ID'], axis=1)

# %%
df
# Out:
#            Name   Type               Breed        Color       Sex   Size
# 0         RAZOR    DOG      BOSTON TERRIER  BLACK/WHITE  Neutered  SMALL  \
# 1           NaN    DOG   GERM SHEPHERD/MIX  BLACK/BROWN  Neutered    MED
# 2           NaN    DOG  SIBERIAN HUSKY/MIX          RED    Female    MED
# 3           NaN    DOG       GERM SHEPHERD  BLACK/BROWN  Neutered    MED
# 4         CHLOE    DOG      SIBERIAN HUSKY  BLACK/WHITE    Female  SMALL
# ...         ...    ...                 ...          ...       ...    ...
# 25430      BUBA    CAT         DOMESTIC SH   GRAY/WHITE  Neutered  SMALL
# 25431  *JESSICA  OTHER            AMERICAN  WHITE/BROWN    Spayed  SMALL
# 25432    SHINER    DOG            PIT BULL    TAN/WHITE  Neutered  LARGE
# 25433   *NEWTON    DOG    CHIHUAHUA SH/MIX  BROWN/WHITE  Neutered  SMALL
# 25434       NaN  OTHER               SHEEP        WHITE    Female  LARGE
#
#       Date Of Birth Kennel Number Intake Date Outcome Date  ...
# 0        10/29/2009         TRUCK  12/26/2022   12/26/2022  ...  \
# 1               NaN          DS53  05/18/2023   05/21/2023  ...
# 2               NaN          DS49  05/18/2023   05/21/2023  ...
# 3               NaN          DS60  05/18/2023   05/21/2023  ...
# 4        05/18/2022          DS62  05/18/2023   05/21/2023  ...
# ...             ...           ...         ...          ...  ...
# 25430    10/15/2017          CA02  10/03/2019   10/23/2019  ...
# 25431    11/08/2017          CA01  06/20/2018   10/10/2018  ...
# 25432    12/22/2012          DS70  09/11/2014   10/02/2014  ...
# 25433    07/28/2011          DS91  07/02/2020   08/20/2020  ...
# 25434           NaN          YARD  03/12/2018   03/13/2018  ...
#
#          Intake Subtype     Outcome Type Outcome Subtype Intake Condition
# 0                 FIELD  RETURN TO OWNER       FLD_IDTAG          UNKNOWN  \
# 1      OVER THE COUNTER         TRANSFER          WONDER          UNKNOWN
# 2      OVER THE COUNTER         TRANSFER          WONDER          UNKNOWN
# 3      OVER THE COUNTER         TRANSFER          WONDER          UNKNOWN
# 4                 FIELD         TRANSFER          WONDER          UNKNOWN
# ...                 ...              ...             ...              ...
# 25430  OVER THE COUNTER         ADOPTION          WALKIN          HEALTHY
# 25431  OVER THE COUNTER         TRANSFER            HSSC          HEALTHY
# 25432  OVER THE COUNTER        EUTHANIZE      AGGRESSIVE      UNTREATABLE
# 25433             FIELD         TRANSFER      ROCKET DOG          HEALTHY
# 25434             FIELD  RETURN TO OWNER             NaN          UNKNOWN
#
#       Outcome Condition Intake Jurisdiction Outcome Jurisdiction
# 0               HEALTHY          SANTA ROSA           SANTA ROSA  \
# 1               HEALTHY              COUNTY               COUNTY
# 2               HEALTHY              COUNTY               COUNTY
# 3               HEALTHY              COUNTY               COUNTY
# 4               HEALTHY              COUNTY               COUNTY
# ...                 ...                 ...                  ...
# 25430           HEALTHY          SANTA ROSA          *HEALDSBURG
# 25431           HEALTHY          SANTA ROSA               COUNTY
# 25432       UNTREATABLE          SANTA ROSA               COUNTY
# 25433           HEALTHY          SANTA ROSA        OUT OF COUNTY
# 25434               NaN              COUNTY               COUNTY
#
#       Outcome Zip Code                     Location  Count
# 0              95404.0  95404(38.43807, -122.71247)      1
# 1              94951.0  94951(38.29715, -122.66645)      1
# 2              94951.0  94951(38.29715, -122.66645)      1
# 3              94951.0  94951(38.29715, -122.66645)      1
# 4              94951.0  94951(38.29715, -122.66645)      1
# ...                ...                          ...    ...
# 25430          95448.0  95448(38.61064, -122.86883)      1
# 25431          95407.0  95407(38.41483, -122.72707)      1
# 25432          95476.0  95476(38.29188, -122.45728)      1
# 25433          94146.0                        94146      1
# 25434          95472.0  95472(38.40179, -122.82512)      1
#
# [25435 rows x 22 columns]

# %%
unique_names = df['Name'].unique().tolist()
unique_names
# Out:
# ['RAZOR',
#  nan,
#  'CHLOE',
#  'MAX',
#  'OSO',
#  'FELLA',
#  'PUDGY',
#  'LEXI',
#  'KENJI',
#  'SONOMA',
#  'COCO',
#  '*TABITHA',
#  'NAKITA',
#  '*PEPPER',
#  'SATIN',
#  'PENNY',
#  'SIR DUNCAN NEPAL',
#  '*RYAN',
#  'POPPY',
#  '*MICHAELA',
#  '*SQUID',
#  'JAY',
#  'DRAGON',
#  'HOUDINI',
#  'MILLIE',
#  'NALA',
#  'MACK',
#  'SNOWY',
#  '*TED',
#  'BENTLEY',
#  'CLOE',
#  'VINNIE',
#  '*SPROUT',
#  'BENJIE',
#  'SMOKEY',
#  'BEA',
#  'POE',
#  'NOVA',
#  'CHICO',
#  'ZEUS',
#  '*JENNY',
#  'TURKEY VULTURE',
#  'HORATIO',
#  'CENNORS',
#  'MANDY',
#  'SASHA',
#  'MOCHI',
#  '*CHECKERS',
#  'NICKI',
#  '*CODY',
#  '*LUZ',
#  'MITCH',
#  '*GINNY',
#  'WIZARD',
#  '*CASHEW',
#  'BRUNO',
#  'CASH',
#  'CHIQUIO',
#  '*GRACE',
#  'TANK',
#  '*TWINKLES',
#  'HAMMY',
#  'LOBO',
#  '*PHOENIX',
#  '*TUCKER',
#  'PIGGY PIGGY',
#  '*GEORGE',
#  '*MULAN',
#  'KITTY KITTY',
#  'ALEX',
#  'BRUTIE',
#  '*SPARKLE',
#  '*SHINE',
#  '*LILLY',
#  'LITA',
#  '*FREDDY',
#  'NINA BEAR',
#  'TOMMY',
#  'SELVA',
#  'LITTLE BUDDY',
#  'NINA',
#  'OREO',
#  'ROCKY',
#  'OSSO',
#  '*LUCKY',
#  '*BUTTERCUP',
#  'KITTY BOY',
#  'INO',
#  'LISTO',
#  '*MILA',
#  'PANDA',
#  '*NALA',
#  '*SID',
#  '*BRIAN',
#  '*SPRECKLES',
#  '*KIT',
#  'DELILAH',
#  'MOMMY',
#  '*BILLY',
#  'KALLITA',
#  '*PIE',
#  '*SADIE',
#  'LUKAS',
#  '*SULLI',
#  '*CUTIE',
#  'AUDIE',
#  '*GALAPAGOS',
#  'SALLY',
#  'ROSIE',
#  'DEXTER',
#  'CARTMAN',
#  'ENZO',
#  'KILLIAN',
#  'SPOT',
#  'COCO CHANEL',
#  'SCRAPPY',
#  '*CHANCE',
#  '*CLOWN',
#  '*PERSIMMON',
#  '*JULIETTE',
#  'SAMMY',
#  '*VIXEN',
#  'MILO',
#  '* ROBIN',
#  'YOGI',
#  'BUDDY',
#  'PEACH',
#  '*BOOTSIE',
#  'PELUSA',
#  '*ALVIE',
#  '*STELLA',
#  '*LLOYD',
#  'HAZLE',
#  'COOKIE',
#  '*HONEY',
#  'SATIVA',
#  '*ASTRO',
#  '*TANGO',
#  '*AVA',
#  '*SQUEAK',
#  'CITALI',
#  'SNICKERS',
#  'KORA',
#  'HASHI',
#  '*TILLY',
#  '*OISHI',
#  '*APOLLO',
#  '*ZOOM',
#  'LOU',
#  'CHELSEA',
#  '*MOCHA',
#  '*LONNIE',
#  'BANDIT',
#  '*LUCY',
#  '*MALCOLM',
#  'LUCAS',
#  '*SPROCKET',
#  'DAISY',
#  'JAEGER',
#  'TIGER',
#  'JACK',
#  '*BUTTERBALL',
#  'LEMMY',
#  'SHADOW',
#  'DIOR',
#  'NEWTON',
#  'ESME',
#  '*PHILLIP',
#  '*LOCKET',
#  'MAGGIE',
#  '*ROCKET',
#  'TYGA',
#  'CAT',
#  'DESI LU',
#  'DIPPER',
#  'DAKOTA',
#  'MIA',
#  '*LATTE',
#  '*CANDY',
#  '*WIDGET',
#  'ANGUS',
#  '*PRETZEL',
#  'MUFASA',
#  'CANELO',
#  'KELLIE',
#  '*CHESS',
#  'BUSTER',
#  '*POCKET',
#  '*BEANS',
#  'LUNA',
#  'FETCH',
#  '*JOHNNY',
#  '*RADISH',
#  'JAX',
#  'BELLA',
#  'PRINCE HENRY',
#  '*GLADYS',
#  'POCHO',
#  'LEO',
#  '*KEANU',
#  'STELLA',
#  'BOON',
#  'CANELA',
#  'ARLO',
#  'LOU DOG',
#  '*BASIL',
#  'DIESEL',
#  'KEROK',
#  'BONES',
#  'BENNY',
#  'CHIQUIS',
#  'OATIE',
#  '*TAMMY',
#  'ZIMA',
#  'COWBOY',
#  '*PYRITE',
#  '*OBSIDIAN',
#  '*CELESTITE',
#  'COOPER',
#  'DOZER',
#  'JASMINE',
#  'CHICA',
#  'LOLA',
#  'CAPTAIN',
#  '*DOTTIE',
#  '*TURNER',
#  '*BETH',
#  '*KELLY',
#  '*MELVIN',
#  '*JOE',
#  'PELUCI',
#  'DELTA',
#  'DANIKA',
#  'ROCCO',
#  'ANNIE',
#  '*MEG',
#  '*SLEEPY',
#  '*JUNE',
#  'WALDO',
#  '*ONYX',
#  '*BAMBI',
#  '*SAPHIRA',
#  '*BITSY',
#  'MAZIE',
#  '*TOPAZ',
#  '*AGATE',
#  '*GALENA',
#  '*MOONSTONE',
#  '*HUCKLEBERRY',
#  'DODGER',
#  'BLANCA',
#  '*MUNCHIE',
#  '*RUFUS',
#  '*CHAMP',
#  'TRIME',
#  '*MELODY',
#  'EMMA LOU',
#  'SOYA',
#  'UZI',
#  '*GERTRUDE',
#  'CREEK',
#  '*GRAHAM',
#  '*VINCE',
#  'BUTTERCUP',
#  'RUTHIE',
#  'BENJI',
#  'RICKY',
#  'NALU',
#  '*PO BOY',
#  'CHAOS',
#  'MESCAL',
#  '*PAULA',
#  'AZURA',
#  'BRUCE',
#  'LEIA',
#  'BLUES CLUES',
#  '*WENDY',
#  'ZEKE',
#  '*JOKER',
#  '*RALPHIE',
#  'SUZIE',
#  '*COOPER',
#  '*CHARLIE',
#  '*BREE',
#  '*MABLE',
#  'BEANS',
#  'MOONSHINE',
#  'IAMIYE',
#  '*VALERIE',
#  'TAZ',
#  'ODOM',
#  'MUTT MUTT',
#  'LILAC',
#  'J LO',
#  '*BEIBER',
#  'JADA',
#  'COCONUT',
#  '*STAR',
#  'RA',
#  '*WEDNESDAY',
#  'SIMBA',
#  'LUCY',
#  '*VINCENZO',
#  'THOR',
#  'TOHUE',
#  'LOSI',
#  'MOMMA',
#  'MISSY',
#  'MARLEY',
#  'VENOM',
#  '*MURRAY',
#  '*BEIGNET',
#  '*MURPHEY',
#  'JACKA',
#  '*BEAN',
#  'PENNI',
#  'COSMO',
#  'THUMPER',
#  'SAGERY',
#  'ROISE',
#  'PUMKIN',
#  'KONG',
#  'CHAPOLIN',
#  'CODY',
#  'CALLIE',
#  'FRANKIE',
#  '*SNOWEY',
#  'MARGUERITE',
#  '*AMBER',
#  '*JOAN',
#  'WHITE TIP',
#  'PUBA',
#  'HARLEY',
#  '*DEACON',
#  'CHOCOLATE MOUSSE',
#  'CHIQUILLO',
#  '*TURBO',
#  '*BELLA',
#  'BOBBY',
#  'ROXY',
#  '*BODHI',
#  '*MAGIC',
#  '*MAVIS',
#  '*LILY',
#  'ABBY',
#  '*AVALANCHE',
#  '*LUDWIG',
#  'ATHENA',
#  'ALORA',
#  'LARRY',
#  'PHEONIX',
#  '*JUPITER',
#  'CINDY LOU',
#  'CHARLOTTE',
#  '29102',
#  'SKIPPER',
#  '*ST JOHN',
#  'FRAULEIN',
#  'COAL',
#  'BOB',
#  '29101',
#  'ELIANA',
#  'T-BONE',
#  '*TRINKA',
#  '*SUNNY',
#  'LITTLE GREY',
#  'LILO',
#  'KILO',
#  'PHYSLIE',
#  'ARCHIE',
#  'TEM',
#  'JAKE',
#  '*CINNAMON TOAST',
#  'MAC',
#  '*ABBY',
#  'BOWSER',
#  'MUSHI',
#  'DORRIS',
#  'HEIDI',
#  'SILVER',
#  '*TULIP',
#  '*VERUCA',
#  '*PEPA',
#  'BOO',
#  'BABY',
#  '*RICO',
#  'BILLY',
#  'BRANDY',
#  'LILLY',
#  '*VELVET',
#  'CHANEL',
#  '*RUBY',
#  '*KORU',
#  'PRINCETON',
#  'SISSY',
#  'BUDDY BOY',
#  'CAVA',
#  '*ELMO',
#  'CHA CHA',
#  '*LIONEL',
#  '*BUSTER',
#  '*BOUNCE',
#  'BODHI',
#  '*ANNIE',
#  'LUCA',
#  '*PEBBLES',
#  'HAMLET',
#  'PEPPER',
#  '*MARLEY',
#  'MOJO',
#  'PELUCHIN',
#  '*GIMLI',
#  '*GANDALF',
#  'BOBO',
#  'PHIL',
#  '*WHITNEY',
#  'NALLIE',
#  '*MUNCHKIN',
#  'DAIMOKU',
#  '*BLUE',
#  '*DEE',
#  '*STRAWBERRY',
#  'RENCO',
#  '*ORA',
#  '*ARTURO',
#  'PRINCESS',
#  'ZIGGY',
#  'GOOFY',
#  'SPUTTY',
#  '*TWITCH',
#  'LILLITH',
#  'CUCA',
#  'ZOE',
#  'JUNI',
#  'ZELDA',
#  'WOLFY',
#  'MINI',
#  'LOUIE',
#  '*AMY',
#  '*COFFEE',
#  '*MYYA',
#  'BLUE',
#  'MAVERICK',
#  '*PAPRIKA',
#  'RIFF',
#  '*BEET',
#  '*ERNIE',
#  '*WOMBAT',
#  'KYA',
#  'LILY',
#  'KATNISS',
#  'POPPA',
#  'JUDGE',
#  '*PAPYA',
#  '*YASHA',
#  'GRACE',
#  '*ASH',
#  '*ROMAN',
#  'BISTO',
#  'JOCKO',
#  'ZUMA',
#  'EOWYN',
#  '*BERT',
#  '*OSCAR',
#  'MUNEQA',
#  '*TREJO',
#  'KALI',
#  'STERLING',
#  'SYLVESTER',
#  'BARKLEY',
#  'CHUY',
#  '*STONE',
#  '*PETEY',
#  'SNOW',
#  '*RED  EAR SLIDER',
#  '*HERCULES',
#  'JARA',
#  '*NEENA',
#  '*MARTA',
#  '*TEDDY',
#  'JOSIE',
#  '*LINUS',
#  '*MONKEY',
#  '*NELLIE',
#  'MAE',
#  'ACE',
#  '*RUMBLE',
#  '*COLLET',
#  '*ABEL',
#  '*BIG MAC',
#  'TUFFY/SCOOCH',
#  'BAGEL',
#  'HALO',
#  '*SCARLET',
#  '*ATLAS',
#  '*BONNIE',
#  '*BLANCHE',
#  'YOHALLI',
#  '*YETI',
#  '*TIKI',
#  '*RIGATONI',
#  '*RAVIOLI',
#  '*ALFREDO',
#  '*MAYA',
#  'MOON',
#  'BABO',
#  '*RUSS',
#  'STACEY',
#  'BOONE',
#  'ROLO',
#  'CHARLO',
#  '*MOON',
#  'KEVIN',
#  'KODA',
#  '*WILSON',
#  'NYLA',
#  '*NORI',
#  '*NANCY',
#  '*CARROT',
#  '*TOFU',
#  'HERSHEY',
#  'TILLIPPI',
#  '*MISO',
#  'MARIPOSA',
#  'SAGE',
#  'MONTANA',
#  '*CHINOOK',
#  'SIS',
#  '*LINX',
#  'KAI',
#  '*RUE',
#  'SEDONA',
#  '*GAMBIT',
#  '*KINX',
#  '*NOLAN',
#  'PIANO',
#  'INDIGO',
#  '*BLUEBERRY',
#  'ANGEL',
#  'OLLIE',
#  'SAMSON',
#  'JUNGLE',
#  'PEPITO',
#  'BROOK',
#  'PRINCESS MELODY WINGNUT',
#  '*GUMBO',
#  'NIYA',
#  'FRANK',
#  '*SHELBY',
#  'KIEKIE',
#  'BADGER',
#  '*IKE',
#  'CHARLIE',
#  'PEARL',
#  'MEI',
#  'RINGO',
#  '*PAUL',
#  'MAJOR',
#  'TYSON',
#  'BOND',
#  'FRIDA',
#  'ZIPPER',
#  'COCOA',
#  '*NACHO',
#  '*HAMLET',
#  'MIIDNIITE',
#  '*THOREAU',
#  'LACY',
#  'RUBI',
#  'TOBIKO',
#  'TIMBER',
#  '*CHOMPER',
#  'HENRY',
#  '*APPLE',
#  '*RANDY',
#  '*WRINKLES',
#  'CASPER',
#  '*MISTY',
#  '*SMOKEY',
#  'SPOOKY',
#  'LETTY LOU',
#  'CHIEF',
#  'DIXIE',
#  'RISHI',
#  '*HENRY',
#  'SHILO',
#  '*JENNA',
#  '*ZING',
#  '*BRITTANY',
#  '*DAVID',
#  '*TANNER',
#  'JAKE GRAY',
#  '*ZIPPY',
#  'PIERRE',
#  'TILLY',
#  '*RICK',
#  'KYE',
#  'GEORGE',
#  '*RANGER',
#  'WILLOW',
#  'GRACIE',
#  '*MANNY',
#  'BLU',
#  'CARROT',
#  'VALENTINO',
#  '*ED',
#  'LOLLI',
#  'TUDEY',
#  '*NIFTY',
#  'BALOO BEAR',
#  'HOBBS',
#  'KRACKEN',
#  'CAT 4',
#  'CHIQUITA',
#  'PAYBACK',
#  '*MINX',
#  '*TINA',
#  'NOODLE',
#  'ADDIE',
#  '*TATER TOT',
#  'CUJO',
#  'SADY',
#  'BUDDY B',
#  '*SPUD',
#  '*SPIKE',
#  'KIKO',
#  '*BALTHAZAR',
#  'QUINN',
#  'SIMIWAH',
#  'FRED',
#  '*CHAI',
#  '*ROCKY',
#  'WHISKEY',
#  'KRATOSS',
#  'RED',
#  '*PLATYPUS',
#  '*BUTTERNUT',
#  'BRIGIT',
#  'U.D.',
#  '*ENZO',
#  'ROACH',
#  '*JACK',
#  'MILA',
#  'ROWAN',
#  'SPONGE BOB',
#  'SQUARE PANTS',
#  'GRIZ',
#  'KNUCKLES',
#  '*KAMALA',
#  'WREN',
#  '29207',
#  '29209',
#  'LUCKY',
#  '29206',
#  '*SAGE',
#  '29208',
#  '29203',
#  '29204',
#  '29205',
#  '*ALLIE',
#  '*ROSIE',
#  '*CHOCOCAT',
#  '*BADGER',
#  '*MAPLE',
#  'SWISHER',
#  '*JADE',
#  'DIRTY GIRL',
#  'MOBY',
#  'LADY',
#  '*FREYA',
#  'NINJA',
#  '*BUTTON',
#  'FOXY',
#  '*CINNAMON',
#  'RUFFIO',
#  '*BABY HAM',
#  '*DUCKIE',
#  '*PORKCHOP',
#  'DUECE',
#  'CLEO',
#  'MILES',
#  'BRAUNIE',
#  '*SALLY',
#  'NESSIE',
#  'GUNNER',
#  'FELON',
#  'DOGE',
#  'MAILO',
#  'SUKI',
#  'KING',
#  'ZORA',
#  'APOLO',
#  'SAVANNAH',
#  '*GIZMO',
#  'JOHNY CASH',
#  'JUNE',
#  'LEX',
#  'SKYE',
#  'PONG',
#  'CABRON',
#  'PING',
#  'MITTENS',
#  '*FIONA',
#  'BLACKIE',
#  '*HOLLANDAISE',
#  'TRINITY',
#  'MISSY BLUE',
#  'BEAR',
#  '*KIRBY',
#  'HANK',
#  'KOA',
#  '*VINNIE',
#  'CEIGE',
#  '*DARCY',
#  'PANCHITO',
#  'MOLLY',
#  'DOLCE',
#  '*TUNDRA',
#  'FIONA DAENERYS',
#  'DAISY I',
#  'TOBY',
#  '*STRIPES',
#  'KOFFEE',
#  'ANDROMEDA',
#  '*MILTON',
#  'TAMMY',
#  '*COLT',
#  '*NAN',
#  '*CUPID',
#  'SUNNY',
#  'TIGER KITTY',
#  'LOKI',
#  '*TOBY',
#  'TIBBY',
#  'PUFFY',
#  'BON BON',
#  '*JAMBALYA',
#  'ARIA',
#  'SOCHI',
#  'ESCOBAR',
#  'NUM NUM',
#  '*MARINARA',
#  'ROSCOE',
#  '*MARNIE',
#  'KITTLE',
#  'HARLO',
#  '*TWIX',
#  '*SPOT',
#  'FLUFFY',
#  '*CALLIOPE',
#  'BEAUTY',
#  'JELLY BEAN',
#  '*NITRO',
#  'YOSHI',
#  '*MAUDE',
#  '*LIAM',
#  '*MILO',
#  '*TROY',
#  '*ROSA',
#  'BINX',
#  'CARMELA',
#  '*SLY',
#  'ZENA',
#  '*LITTLE GUY',
#  '7',
#  '13',
#  '49',
#  '50',
#  '51',
#  '42',
#  '29',
#  '55',
#  '36',
#  '9',
#  '53',
#  '46',
#  '63',
#  '17',
#  '30',
#  '10',
#  '40',
#  '48',
#  '8',
#  '4',
#  '23',
#  '34',
#  '47',
#  '56',
#  '62',
#  '3',
#  '18',
#  '37',
#  '61',
#  '24',
#  '14',
#  '2',
#  '32',
#  '54',
#  '11',
#  '60',
#  '33',
#  '52',
#  '59',
#  '66',
#  '5',
#  '1',
#  '22',
#  '25',
#  '58',
#  '28',
#  '6',
#  '26',
#  '31',
#  '21',
#  '19',
#  '35',
#  '64',
#  '44',
#  '39',
#  '43',
#  '15',
#  '67',
#  '16',
#  '12',
#  '27',
#  '45',
#  '41',
#  '65',
#  '38',
#  '57',
#  '20',
#  'GRUMPY',
#  'DRACO',
#  '*THEODOR',
#  '*LEMON',
#  '*LOUIE',
#  'MICKEY',
#  '*CHARLOTTE',
#  '*JOEY',
#  '*OLLIE',
#  '*CASS',
#  '*DATU',
#  'LITTLE',
#  '*FAITH',
#  '*YOSHI',
#  '*PARSLEY',
#  'JACOB',
#  'EMMA',
#  '*DORA',
#  'NEYO',
#  'CRIKEY',
#  'NILA',
#  'PHILO',
#  'BIGGIE',
#  'BESOS',
#  'PUP',
#  'JOE',
#  '*THYME',
#  'KIMURA',
#  'CHICHARRON',
#  'REGALITO',
#  'CHICKEN',
#  'LOVE',
#  'HAZEL',
#  'JIBBY',
#  'WALLY',
#  'CHANCE',
#  'SWEETPEA',
#  '*CLYDE',
#  '*KATIE',
#  'MOCHA',
#  '*HANNAH',
#  '*SUZIE',
#  'ONIN',
#  'LAYLA',
#  '*STAN',
#  '*CHANDLER',
#  'BUBBLES',
#  '*NEEZEY',
#  'GRENVILLE',
#  'JUNIPER',
#  'COFFEE',
#  'QUAKE',
#  'ONIX',
#  'FLOKI',
#  '*EDISON',
#  'SUSIE',
#  'DUDLEY',
#  '*MILLIE',
#  'SAM',
#  '*CADE',
#  'BUTTONS',
#  'SANDY',
#  'LEA',
#  'RON',
#  '*TRACEY',
#  'PHOEBE',
#  'VENUS',
#  'LEE',
#  'LIGHTNING BOLT',
#  '*SPARKY',
#  'SCAMPI',
#  '*JESSICA',
#  'ANDY',
#  '*FEZZIK',
#  'SOFIA',
#  'SADIE',
#  'TRIX',
#  'OGGY',
#  'MALITIA',
#  'AMBER',
#  '*CHASE',
#  'CHOCOLATE',
#  'MUSHROOM',
#  'EVEREST',
#  'STORMY',
#  '*BOOTIE',
#  'MYA',
#  '*ARCHIE',
#  'JERRY',
#  'SUNDAY',
#  'CABO',
#  '*BRADLEY',
#  'FALKOR',
#  '*MADDIE',
#  '*ASHLEY',
#  '*DANI',
#  'CHICHI',
#  'ARIES',
#  'JASPER',
#  '*GINGER',
#  'MAGGY',
#  '*LINDSEY',
#  '*ORION',
#  '*FUDGE',
#  'BULLET',
#  'BILLIE',
#  'MARY',
#  'TOMY',
#  '*MINNIE',
#  '*LOUIS',
#  '*FRANKY',
#  'CHICK',
#  'TONKA',
#  'DOLLY',
#  'RYDER',
#  'GUS',
#  '*POOKIE',
#  'LEWA',
#  'CHEWY',
#  'TRIXI',
#  '*ITSY',
#  'DIEGO',
#  'COMPANA',
#  '*BINX',
#  'SHAMUS',
#  'FELONI',
#  'PINTA',
#  'TOBIAS',
#  'OLAF',
#  '*ROCKELLE',
#  'DANTE',
#  '*SUGAR',
#  'ABIGAIL',
#  '*MISKA',
#  'CHUNKY',
#  '*PANAMA',
#  'PACO',
#  '*SATURN',
#  'ROSAY',
#  'ODIN',
#  '*BLANCA G.',
#  'BUBBA',
#  'HONEY',
#  'MAC MOE',
#  'SPARK',
#  '*PEGGY BUNKER',
#  'CHOPPER',
#  '*CHEERIOS',
#  'PETUNIA',
#  'KIRBY',
#  'LUKE',
#  'ECHO',
#  'SQUIRT',
#  '*CHEVY',
#  'AGAPE',
#  'MURPHY',
#  'SKINNY',
#  'DUKE',
#  '*TORI',
#  'SARANEE',
#  'VADAR',
#  'FINNEGAN',
#  '*COURTNEY',
#  '*BAMBINO',
#  'MOPS',
#  'ROMEO',
#  'BILLIE JEAN',
#  'DELIAH',
#  'GORDO',
#  ...]

# %%
df['Name'] = df['Name'].str.replace('*', '')
df['Name']
# Out:
# 0          RAZOR
# 1            NaN
# 2            NaN
# 3            NaN
# 4          CHLOE
#           ...
# 25430       BUBA
# 25431    JESSICA
# 25432     SHINER
# 25433     NEWTON
# 25434        NaN
# Name: Name, Length: 25435, dtype: object

# %%
df.dtypes
# Out:
# Name                     object
# Type                     object
# Breed                    object
# Color                    object
# Sex                      object
# Size                     object
# Date Of Birth            object
# Kennel Number            object
# Intake Date              object
# Outcome Date             object
# Days in Shelter          object
# Intake Type              object
# Intake Subtype           object
# Outcome Type             object
# Outcome Subtype          object
# Intake Condition         object
# Outcome Condition        object
# Intake Jurisdiction      object
# Outcome Jurisdiction     object
# Outcome Zip Code        float64
# Location                 object
# Count                     int64
# dtype: object

# %%
df = df.drop('Location', axis=1)

# %%
unique_types = df['Type'].unique().tolist()
unique_types
# Out:
# ['DOG', 'OTHER', 'CAT']

# %%
otherAnimals = df[df["Type"] == "OTHER"]
otherAnimals
# Out:
#           Name   Type              Breed        Color      Sex   Size
# 5          NaN  OTHER             PIGEON   GRAY/WHITE  Unknown  SMALL  \
# 12         NaN  OTHER                BAT        BLACK  Unknown  SMALL
# 14      SONOMA  OTHER              HORSE  BROWN/BLACK   Female  LARGE
# 17         NaN  OTHER  BAT/MEX FREE-TAIL         GRAY  Unknown  SMALL
# 20       SATIN  OTHER              HORSE  BLACK/WHITE   Female  LARGE
# ...        ...    ...                ...          ...      ...    ...
# 25320      NaN  OTHER          RABBIT SH  BLACK/WHITE  Unknown  SMALL
# 25400      NaN  OTHER            CHICKEN        BROWN   Female  SMALL
# 25423      NaN  OTHER                BAT        BROWN  Unknown  SMALL
# 25431  JESSICA  OTHER           AMERICAN  WHITE/BROWN   Spayed  SMALL
# 25434      NaN  OTHER              SHEEP        WHITE   Female  LARGE
#
#       Date Of Birth Kennel Number Intake Date Outcome Date  ... Intake Type
# 5               NaN         TRUCK  03/15/2023   03/15/2023  ...       STRAY  \
# 12              NaN          EUTH  03/13/2023   03/13/2023  ...  QUARANTINE
# 14              NaN        CHANGE  11/15/2021   03/15/2023  ...  CONFISCATE
# 17              NaN         TRUCK  03/15/2023   03/15/2023  ...  QUARANTINE
# 20              NaN        CHANGE  11/15/2021   03/15/2023  ...  CONFISCATE
# ...             ...           ...         ...          ...  ...         ...
# 25320    06/23/2016          CA01  06/23/2016   06/23/2016  ...       STRAY
# 25400           NaN          LS01  02/01/2019   02/14/2019  ...       STRAY
# 25423           NaN         TRUCK  08/18/2020   08/18/2020  ...  QUARANTINE
# 25431    11/08/2017          CA01  06/20/2018   10/10/2018  ...       STRAY
# 25434           NaN          YARD  03/12/2018   03/13/2018  ...       STRAY
#
#          Intake Subtype     Outcome Type Outcome Subtype Intake Condition
# 5                 FIELD        EUTHANIZE      INJ SEVERE          UNKNOWN  \
# 12                FIELD        EUTHANIZE             FRA          UNKNOWN
# 14           FLD_HOSPTL         TRANSFER             NaN          UNKNOWN
# 17                FIELD        EUTHANIZE             FRA          UNKNOWN
# 20           FLD_HOSPTL         TRANSFER             NaN          UNKNOWN
# ...                 ...              ...             ...              ...
# 25320         BORN_HERE        EUTHANIZE      UNDERAGEWT      UNTREATABLE
# 25400             FIELD         ADOPTION        FB OTHER          UNKNOWN
# 25423             FIELD              NaN             NaN          UNKNOWN
# 25431  OVER THE COUNTER         TRANSFER            HSSC          HEALTHY
# 25434             FIELD  RETURN TO OWNER             NaN          UNKNOWN
#
#       Outcome Condition Intake Jurisdiction Outcome Jurisdiction
# 5               HEALTHY          SANTA ROSA                  NaN  \
# 12          UNTREATABLE              COUNTY                  NaN
# 14      TREATABLE/REHAB              COUNTY               COUNTY
# 17              HEALTHY              COUNTY                  NaN
# 20      TREATABLE/REHAB              COUNTY               COUNTY
# ...                 ...                 ...                  ...
# 25320       UNTREATABLE              COUNTY                  NaN
# 25400           PENDING              COUNTY        OUT OF COUNTY
# 25423               NaN              COUNTY                  NaN
# 25431           HEALTHY          SANTA ROSA               COUNTY
# 25434               NaN              COUNTY               COUNTY
#
#       Outcome Zip Code  Count
# 5                  NaN      1
# 12                 NaN      1
# 14             95404.0      1
# 17                 NaN      1
# 20             95404.0      1
# ...                ...    ...
# 25320              NaN      1
# 25400          95482.0      1
# 25423              NaN      1
# 25431          95407.0      1
# 25434          95472.0      1
#
# [2135 rows x 21 columns]

# %%
uniqueBreedsOfDifferentAnimals = otherAnimals['Breed'].value_counts().to_dict()
uniqueBreedsOfDifferentAnimals
# Out:
# {'CHICKEN': 419,
#  'RABBIT SH': 364,
#  'BAT': 244,
#  'GUINEA PIG': 114,
#  'GOAT': 95,
#  'SHEEP': 64,
#  'HORSE': 49,
#  'RAT': 49,
#  'PIG': 47,
#  'PARAKEET': 44,
#  'PIGEON': 34,
#  'KOI': 25,
#  'PEAFOWL': 24,
#  'COCKATIEL': 23,
#  'LOP-MINI': 22,
#  'HAMSTER': 21,
#  'DUCK': 20,
#  'REX': 18,
#  'GOOSE': 18,
#  'RACCOON': 17,
#  'ENGLISH SPOT/MIX': 14,
#  'RABBIT LH': 14,
#  'AMERICAN': 14,
#  'LOP-ENGLISH': 13,
#  'HOTOT': 11,
#  'LOP-HOLLAND': 11,
#  'CANARY': 10,
#  'OPOSSUM': 9,
#  'DUTCH/MIX': 9,
#  'CALIFORNIAN': 8,
#  'CALIFORNIAN/MIX': 8,
#  'LOP-AMER FUZZY': 8,
#  'ENGLISH SPOT': 8,
#  'MOUSE': 8,
#  'FINCH': 8,
#  'GOAT/BOER': 7,
#  'PARROT': 7,
#  'NEW ZEALAND WHT': 7,
#  'GOAT/LA MANCHA': 7,
#  'POTBELLY PIG': 7,
#  'DOVE': 7,
#  'HAVANA/MIX': 7,
#  'BAT/MEX FREE-TAIL': 7,
#  'SKUNK': 7,
#  'TURTLE': 7,
#  'DUTCH': 6,
#  'REX/MIX': 6,
#  'BOER': 5,
#  'TROPICAL': 5,
#  'NETHERLND DWARF': 5,
#  'HAVANA': 5,
#  'LOP-MINI/MIX': 5,
#  'FOX': 4,
#  'TURKEY': 4,
#  'TORTOISE': 4,
#  'FLEMISH GIANT': 4,
#  'ANGUS': 4,
#  'LOP-ENGLISH/MIX': 4,
#  'MACAW': 4,
#  'GOAT/PYGMY': 4,
#  'LOP-FRENCH': 4,
#  'HOTOT/MIX': 4,
#  'HARLEQUIN/MIX': 3,
#  'ANGORA-SATIN/MIX': 3,
#  'OTHER BIRD': 3,
#  'MULE': 3,
#  'DUCK/CAYUGA': 3,
#  'LIZARD': 3,
#  'LOP-HOLLAND/MIX': 3,
#  'BARRED ROCK': 3,
#  'GOAT/ALPINE': 3,
#  'QUAIL': 3,
#  'QUARTER HORSE': 3,
#  'LOVEBIRD': 3,
#  'CHAMPGN DARGENT': 2,
#  'ARAUCANA': 2,
#  'PALOMINO': 2,
#  'PERUVIAN PASO': 2,
#  'JACK': 2,
#  'MUSCOVY': 2,
#  'REX-MINI/MIX': 2,
#  'AMERICAN/MIX': 2,
#  'CHICKEN/BANTAM': 2,
#  'SQUIRREL': 2,
#  'GOAT/NUBIAN': 2,
#  'RABBIT LH/MIX': 2,
#  'ANGORA-SATIN': 2,
#  'COLD WATER': 2,
#  'CHINCHILLA': 2,
#  'SNAKE': 2,
#  'DONKEY': 2,
#  'LOP-AMER FUZZY/MIX': 2,
#  'LILAC': 2,
#  'DWARF HOTOT': 2,
#  'FERRET': 2,
#  'NEW ZEALAND WHT/MIX': 2,
#  'JERSEY/MIX': 2,
#  'SILVER/MIX': 2,
#  'POLISH': 2,
#  'RHINELANDER/MIX': 2,
#  'DUCK/MUSCOVY': 2,
#  'HERON': 1,
#  'ANGORA-FRENCH/FLEMISH GIANT': 1,
#  'AMERICAN SABLE/MIX': 1,
#  'SHETLAND': 1,
#  'DEGU': 1,
#  'LEGHORN': 1,
#  'ALPINE/MIX': 1,
#  'SATIN': 1,
#  'ARABIAN': 1,
#  'PALOMINO/MIX': 1,
#  'BELGIAN HARE/MIX': 1,
#  'PONY': 1,
#  'HORSE/PAINT': 1,
#  'CHECKERED GIANT': 1,
#  'APPALOOSA': 1,
#  'PYGMY': 1,
#  'JERSEY': 1,
#  'SNAKE/RATTLE': 1,
#  'THOROUGHBRED': 1,
#  'NETHERLND DWARF/MIX': 1,
#  'AMERICAN/REX': 1,
#  'RHODE ISLAND': 1,
#  'HIMALAYAN/MIX': 1,
#  'PAINT': 1,
#  'HAWK': 1,
#  'FLORIDA WHITE': 1,
#  'LA MANCHA': 1,
#  'SILVER': 1,
#  'COCKATOO': 1,
#  'BANTAM': 1,
#  'CONURE': 1,
#  'BUDGERIGAR': 1,
#  'ANGORA-ENGLISH': 1,
#  'LLAMA': 1}

# %% [markdown]
# Zbiór zwiera różne zwierzęta

# %%
topTenBreeds = df["Breed"].value_counts().head(10)
topTenBreeds = topTenBreeds.to_dict()
plt.figure(figsize=(20,10))
plt.bar(topTenBreeds.keys(), topTenBreeds.values())
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# plt.figure(figsize=(10, 6))
# plt.bar(df['Color'], df['Days in Shelter'])
# plt.xlabel('Kolor psa')
# plt.ylabel('Dni w schronisku')
# plt.title('Zależność dni w schronisku względem koloru psa')
# plt.xticks(rotation=45)
# plt.show()

# %%
df = df.drop('Outcome Zip Code', axis=1)
df = df.drop('Intake Date', axis=1)
df = df.drop('Outcome Date', axis=1)
df = df.drop('Outcome Type', axis=1)
df = df.drop('Outcome Subtype', axis=1)
df = df.drop('Kennel Number', axis=1)
df = df.drop('Intake Jurisdiction', axis=1)
df = df.drop('Name', axis=1)

# %%
df = df.drop('Outcome Condition', axis=1)
df = df.drop('Outcome Jurisdiction', axis=1)
df = df.drop('Count', axis=1)

# %%
df.drop(df[df["Days in Shelter"] == "0"].index, inplace=True)
df
# Out:
#         Type               Breed        Color       Sex   Size Date Of Birth
# 1        DOG   GERM SHEPHERD/MIX  BLACK/BROWN  Neutered    MED           NaN  \
# 2        DOG  SIBERIAN HUSKY/MIX          RED    Female    MED           NaN
# 3        DOG       GERM SHEPHERD  BLACK/BROWN  Neutered    MED           NaN
# 4        DOG      SIBERIAN HUSKY  BLACK/WHITE    Female  SMALL    05/18/2022
# 7        CAT         DOMESTIC LH   GRAY/WHITE    Spayed  SMALL    06/26/2011
# ...      ...                 ...          ...       ...    ...           ...
# 25430    CAT         DOMESTIC SH   GRAY/WHITE  Neutered  SMALL    10/15/2017
# 25431  OTHER            AMERICAN  WHITE/BROWN    Spayed  SMALL    11/08/2017
# 25432    DOG            PIT BULL    TAN/WHITE  Neutered  LARGE    12/22/2012
# 25433    DOG    CHIHUAHUA SH/MIX  BROWN/WHITE  Neutered  SMALL    07/28/2011
# 25434  OTHER               SHEEP        WHITE    Female  LARGE           NaN
#
#       Days in Shelter Intake Type    Intake Subtype Intake Condition
# 1                   3       STRAY  OVER THE COUNTER          UNKNOWN
# 2                   3       STRAY  OVER THE COUNTER          UNKNOWN
# 3                   3       STRAY  OVER THE COUNTER          UNKNOWN
# 4                   3       STRAY             FIELD          UNKNOWN
# 7                   4       STRAY             FIELD          UNKNOWN
# ...               ...         ...               ...              ...
# 25430              20       STRAY  OVER THE COUNTER          HEALTHY
# 25431             112       STRAY  OVER THE COUNTER          HEALTHY
# 25432              21       STRAY  OVER THE COUNTER      UNTREATABLE
# 25433              49       STRAY             FIELD          HEALTHY
# 25434               1       STRAY             FIELD          UNKNOWN
#
# [20601 rows x 10 columns]

# %%
df["Sex"].unique()
# Out:
# array(['Neutered', 'Female', 'Spayed', 'Male', 'Unknown'], dtype=object)

# %%
df = df.replace("Neutered", "Male")
df = df.replace("Spayed", "Female")

# %%
df["Size"].unique()
# Out:
# array(['MED', 'SMALL', 'KITTN', 'LARGE', 'X-LRG', 'PUPPY', 'TOY', nan],
#       dtype=object)

# %%
df = df.replace("KITTN", "SMALL")
df = df.replace("PUPPY", "SMALL")
df = df.replace("TOY", "SMALL")
df = df.replace("MED", "MEDIUM")
df = df.replace("X-LRG", "LARGE")
df['Size'] = df['Size'].fillna("MEDIUM")

# %%
df["Size"].unique()
# Out:
# array(['MEDIUM', 'SMALL', 'LARGE'], dtype=object)

# %%
df
# Out:
#         Type               Breed        Color     Sex    Size Date Of Birth
# 1        DOG   GERM SHEPHERD/MIX  BLACK/BROWN    Male  MEDIUM           NaN  \
# 2        DOG  SIBERIAN HUSKY/MIX          RED  Female  MEDIUM           NaN
# 3        DOG       GERM SHEPHERD  BLACK/BROWN    Male  MEDIUM           NaN
# 4        DOG      SIBERIAN HUSKY  BLACK/WHITE  Female   SMALL    05/18/2022
# 7        CAT         DOMESTIC LH   GRAY/WHITE  Female   SMALL    06/26/2011
# ...      ...                 ...          ...     ...     ...           ...
# 25430    CAT         DOMESTIC SH   GRAY/WHITE    Male   SMALL    10/15/2017
# 25431  OTHER            AMERICAN  WHITE/BROWN  Female   SMALL    11/08/2017
# 25432    DOG            PIT BULL    TAN/WHITE    Male   LARGE    12/22/2012
# 25433    DOG    CHIHUAHUA SH/MIX  BROWN/WHITE    Male   SMALL    07/28/2011
# 25434  OTHER               SHEEP        WHITE  Female   LARGE           NaN
#
#       Days in Shelter Intake Type    Intake Subtype Intake Condition
# 1                   3       STRAY  OVER THE COUNTER          UNKNOWN
# 2                   3       STRAY  OVER THE COUNTER          UNKNOWN
# 3                   3       STRAY  OVER THE COUNTER          UNKNOWN
# 4                   3       STRAY             FIELD          UNKNOWN
# 7                   4       STRAY             FIELD          UNKNOWN
# ...               ...         ...               ...              ...
# 25430              20       STRAY  OVER THE COUNTER          HEALTHY
# 25431             112       STRAY  OVER THE COUNTER          HEALTHY
# 25432              21       STRAY  OVER THE COUNTER      UNTREATABLE
# 25433              49       STRAY             FIELD          HEALTHY
# 25434               1       STRAY             FIELD          UNKNOWN
#
# [20601 rows x 10 columns]

# %%
df.drop(df[df["Intake Condition"] == "UNKNOWN"].index, inplace=True)
df
# Out:
#         Type             Breed            Color      Sex   Size Date Of Birth
# 9        CAT       DOMESTIC SH  BRN TABBY/WHITE     Male  SMALL    07/06/2018  \
# 16       CAT       DOMESTIC SH            BLACK   Female  SMALL    07/14/2022
# 19       CAT       DOMESTIC SH      BLACK/WHITE     Male  SMALL    08/29/2022
# 24       CAT       DOMESTIC SH      BLACK/WHITE     Male  SMALL    01/12/2022
# 25       CAT       DOMESTIC SH           CALICO   Female  SMALL    04/10/2022
# ...      ...               ...              ...      ...    ...           ...
# 25429    DOG   AUST CATTLE DOG        TAN/BLACK  Unknown  SMALL    02/21/2022
# 25430    CAT       DOMESTIC SH       GRAY/WHITE     Male  SMALL    10/15/2017
# 25431  OTHER          AMERICAN      WHITE/BROWN   Female  SMALL    11/08/2017
# 25432    DOG          PIT BULL        TAN/WHITE     Male  LARGE    12/22/2012
# 25433    DOG  CHIHUAHUA SH/MIX      BROWN/WHITE     Male  SMALL    07/28/2011
#
#       Days in Shelter      Intake Type    Intake Subtype Intake Condition
# 9                   4            STRAY  OVER THE COUNTER          HEALTHY
# 16                 63            STRAY  OVER THE COUNTER          HEALTHY
# 19                 59            STRAY  OVER THE COUNTER          HEALTHY
# 24                 45            STRAY  OVER THE COUNTER          HEALTHY
# 25                 33  OWNER SURRENDER  OVER THE COUNTER          HEALTHY
# ...               ...              ...               ...              ...
# 25429               2            STRAY         BORN_HERE  TREATABLE/REHAB
# 25430              20            STRAY  OVER THE COUNTER          HEALTHY
# 25431             112            STRAY  OVER THE COUNTER          HEALTHY
# 25432              21            STRAY  OVER THE COUNTER      UNTREATABLE
# 25433              49            STRAY             FIELD          HEALTHY
#
# [15238 rows x 10 columns]

# %%
sorted(df["Color"].unique())
# Out:
# ['AGOUTI',
#  'APRICOT',
#  'APRICOT/WHITE',
#  'BL BRINDLE',
#  'BL BRINDLE/GRAY',
#  'BL BRINDLE/TAN',
#  'BL BRINDLE/WHITE',
#  'BLACK',
#  'BLACK/BL BRINDLE',
#  'BLACK/BLACK',
#  'BLACK/BLK SMOKE',
#  'BLACK/BLK TABBY',
#  'BLACK/BLUE MERLE',
#  'BLACK/BLUE TICK',
#  'BLACK/BR BRINDLE',
#  'BLACK/BRN MERLE',
#  'BLACK/BROWN',
#  'BLACK/CHOCOLATE',
#  'BLACK/CREAM',
#  'BLACK/GOLD',
#  'BLACK/GRAY',
#  'BLACK/RED',
#  'BLACK/SILVER',
#  'BLACK/TAN',
#  'BLACK/TRICOLOR',
#  'BLACK/WHITE',
#  'BLACK/YELLOW',
#  'BLK SMOKE',
#  'BLK SMOKE/WHITE',
#  'BLK TABBY',
#  'BLK TABBY/GRAY',
#  'BLK TABBY/TORTIE',
#  'BLK TABBY/WHITE',
#  'BLK TIGER/TAN',
#  'BLONDE',
#  'BLUE',
#  'BLUE CREAM',
#  'BLUE CREAM/BRN TABBY',
#  'BLUE CREAM/CALICO',
#  'BLUE CREAM/TORTIE',
#  'BLUE CREAM/WHITE',
#  'BLUE MERLE',
#  'BLUE MERLE/BLACK',
#  'BLUE MERLE/GRAY',
#  'BLUE MERLE/TAN',
#  'BLUE MERLE/WHITE',
#  'BLUE PT',
#  'BLUE PT/WHITE',
#  'BLUE TABBY',
#  'BLUE TICK',
#  'BLUE TICK/BLACK',
#  'BLUE TIGER',
#  'BLUE/BL BRINDLE',
#  'BLUE/BLACK',
#  'BLUE/BLUE',
#  'BLUE/BR BRINDLE',
#  'BLUE/BROWN',
#  'BLUE/FAWN',
#  'BLUE/GRAY',
#  'BLUE/GREEN',
#  'BLUE/TAN',
#  'BLUE/TRICOLOR',
#  'BLUE/WHITE',
#  'BLUE/YELLOW',
#  'BR BRINDLE',
#  'BR BRINDLE/BL BRINDLE',
#  'BR BRINDLE/BLACK',
#  'BR BRINDLE/BLUE',
#  'BR BRINDLE/FAWN',
#  'BR BRINDLE/GRAY',
#  'BR BRINDLE/TAN',
#  'BR BRINDLE/WHITE',
#  'BRN MERLE',
#  'BRN MERLE/BLACK',
#  'BRN MERLE/BROWN',
#  'BRN MERLE/WHITE',
#  'BRN TABBY',
#  'BRN TABBY/BLACK',
#  'BRN TABBY/BROWN',
#  'BRN TABBY/CALICO',
#  'BRN TABBY/CREAM',
#  'BRN TABBY/GRAY',
#  'BRN TABBY/ORANGE',
#  'BRN TABBY/ORG TABBY',
#  'BRN TABBY/RED',
#  'BRN TABBY/TORTIE',
#  'BRN TABBY/WHITE',
#  'BRN TIGER',
#  'BRN TIGER/TAN',
#  'BRN TIGER/WHITE',
#  'BROWN',
#  'BROWN/BLACK',
#  'BROWN/BR BRINDLE',
#  'BROWN/BROWN',
#  'BROWN/BUFF',
#  'BROWN/GRAY',
#  'BROWN/GREEN',
#  'BROWN/LIVER',
#  'BROWN/RED',
#  'BROWN/SABLE',
#  'BROWN/SILVER',
#  'BROWN/TAN',
#  'BROWN/TRICOLOR',
#  'BROWN/WHITE',
#  'BUFF',
#  'BUFF/BROWN',
#  'BUFF/ORG TABBY',
#  'BUFF/WHITE',
#  'CALICO',
#  'CALICO PT',
#  'CALICO/BLUE CREAM',
#  'CALICO/BRN TABBY',
#  'CALICO/CALICO',
#  'CALICO/GRAY',
#  'CALICO/GRAY TABBY',
#  'CALICO/SEAL PT',
#  'CALICO/SLVR TABBY',
#  'CALICO/WHITE',
#  'CHOC PT',
#  'CHOC PT/WHITE',
#  'CHOCOLATE',
#  'CHOCOLATE/BROWN',
#  'CHOCOLATE/RED',
#  'CHOCOLATE/TAN',
#  'CHOCOLATE/WHITE',
#  'CREAM',
#  'CREAM/BLACK',
#  'CREAM/BROWN',
#  'CREAM/FAWN',
#  'CREAM/GRAY',
#  'CREAM/TAN',
#  'CREAM/WHITE',
#  'CREAM/YELLOW',
#  'CRM TABBY/BROWN',
#  'FAWN',
#  'FAWN/BL BRINDLE',
#  'FAWN/BLACK',
#  'FAWN/BLUE',
#  'FAWN/TAN',
#  'FAWN/WHITE',
#  'FLAME PT',
#  'GOLD',
#  'GOLD/SILVER',
#  'GOLD/WHITE',
#  'GRAY',
#  'GRAY TABBY',
#  'GRAY TABBY/BLUE CREAM',
#  'GRAY TABBY/GRAY',
#  'GRAY TABBY/ORANGE',
#  'GRAY TABBY/TORTIE',
#  'GRAY TABBY/WHITE',
#  'GRAY TIGER',
#  'GRAY TIGER/WHITE',
#  'GRAY/BLACK',
#  'GRAY/BLUE CREAM',
#  'GRAY/BR BRINDLE',
#  'GRAY/BROWN',
#  'GRAY/GRAY',
#  'GRAY/GREEN',
#  'GRAY/ORANGE',
#  'GRAY/PURPLE',
#  'GRAY/SILVER',
#  'GRAY/TAN',
#  'GRAY/TRICOLOR',
#  'GRAY/WHITE',
#  'GRAY/YELLOW',
#  'GREEN',
#  'GREEN/BROWN',
#  'GREEN/PURPLE',
#  'GREEN/YELLOW',
#  'LILAC PT',
#  'LILAC PT/WHITE',
#  'LIVER TICK',
#  'LIVER/TAN',
#  'LIVER/WHITE',
#  'LYNX PT',
#  'LYNX PT/BLACK',
#  'LYNX PT/BRN TABBY',
#  'LYNX PT/CREAM',
#  'LYNX PT/WHITE',
#  'ORANGE',
#  'ORANGE/BLACK',
#  'ORANGE/BUFF',
#  'ORANGE/WHITE',
#  'ORANGE/YELLOW',
#  'ORG TABBY',
#  'ORG TABBY/BLK TABBY',
#  'ORG TABBY/WHITE',
#  'ORG TIGER',
#  'ORG TIGER/WHITE',
#  'PINK',
#  'RED',
#  'RED MERLE',
#  'RED MERLE/WHITE',
#  'RED TICK',
#  'RED TICK/WHITE',
#  'RED/BLACK',
#  'RED/BR BRINDLE',
#  'RED/BROWN',
#  'RED/CREAM',
#  'RED/GRAY',
#  'RED/TAN',
#  'RED/TRICOLOR',
#  'RED/WHITE',
#  'RUDDY',
#  'SABLE',
#  'SABLE/WHITE',
#  'SEAL PT',
#  'SEAL PT/TORTIE',
#  'SEAL PT/WHITE',
#  'SILVER',
#  'SILVER/BROWN',
#  'SILVER/GRAY',
#  'SILVER/TAN',
#  'SILVER/WHITE',
#  'SL LYNX PT/WHITE',
#  'SLVR TABBY',
#  'SLVR TABBY/WHITE',
#  'SLVR TIGER',
#  'TAN',
#  'TAN/BLACK',
#  'TAN/BLUE',
#  'TAN/BR BRINDLE',
#  'TAN/BROWN',
#  'TAN/CREAM',
#  'TAN/FAWN',
#  'TAN/GOLD',
#  'TAN/GRAY',
#  'TAN/RED',
#  'TAN/SABLE',
#  'TAN/SILVER',
#  'TAN/TAN',
#  'TAN/WHITE',
#  'TORTIE',
#  'TORTIE PT',
#  'TORTIE PT/WHITE',
#  'TORTIE/BLACK',
#  'TORTIE/BLUE CREAM',
#  'TORTIE/BRN TABBY',
#  'TORTIE/BROWN',
#  'TORTIE/GRAY',
#  'TORTIE/GRAY TABBY',
#  'TORTIE/ORG TABBY',
#  'TORTIE/TORTIE',
#  'TORTIE/WHITE',
#  'TRICOLOR',
#  'TRICOLOR/BR BRINDLE',
#  'TRICOLOR/BROWN',
#  'TRICOLOR/GRAY',
#  'TRICOLOR/RED MERLE',
#  'TRICOLOR/RED TICK',
#  'TRICOLOR/TRICOLOR',
#  'TRICOLOR/WHITE',
#  'UNKNOWN',
#  'WHITE',
#  'WHITE/APRICOT',
#  'WHITE/BL BRINDLE',
#  'WHITE/BLACK',
#  'WHITE/BLUE',
#  'WHITE/BLUE MERLE',
#  'WHITE/BLUE TABBY',
#  'WHITE/BLUE TICK',
#  'WHITE/BR BRINDLE',
#  'WHITE/BRN TABBY',
#  'WHITE/BROWN',
#  'WHITE/BUFF',
#  'WHITE/CALICO',
#  'WHITE/CHOCOLATE',
#  'WHITE/CREAM',
#  'WHITE/FAWN',
#  'WHITE/GOLD',
#  'WHITE/GRAY',
#  'WHITE/GRAY TABBY',
#  'WHITE/LILAC PT',
#  'WHITE/ORANGE',
#  'WHITE/ORG TABBY',
#  'WHITE/PINK',
#  'WHITE/RED',
#  'WHITE/RED MERLE',
#  'WHITE/SEAL PT',
#  'WHITE/SILVER',
#  'WHITE/TAN',
#  'WHITE/TORTIE',
#  'WHITE/TRICOLOR',
#  'WHITE/WHITE',
#  'WHITE/Y BRINDLE',
#  'WHITE/YELLOW',
#  'Y BRINDLE',
#  'Y BRINDLE/WHITE',
#  'YELLOW',
#  'YELLOW/BLACK',
#  'YELLOW/GOLD',
#  'YELLOW/GREEN',
#  'YELLOW/TAN',
#  'YELLOW/WHITE']

# %%
len(df["Color"].unique())
# Out:
# 295

# %%
def check_and_replace_color(colors):
    unique_colors = {}
    
    for color in colors:
        parts = color.split("/")
        if len(parts) == 2:
            reversed_color = "/".join(reversed(parts))
            if reversed_color in unique_colors:
                unique_colors[color] = unique_colors[reversed_color]
            else:
                unique_colors[color] = color
        else:
            unique_colors[color] = color
    
    updated_colors = [unique_colors[color] for color in colors]
    return updated_colors

# %%
def replace_same_colors(colors):
    updated_colors = []
    
    for color in colors:
        parts = color.split("/")
        if len(parts) == 2 and parts[0] == parts[1]:
            updated_colors.append(parts[0])
        else:
            updated_colors.append(color)
    
    return updated_colors

# %%
not_fixed_colors = df["Color"].copy()
df["Color"] = check_and_replace_color(df["Color"])
df["Color"] = replace_same_colors(df["Color"])

# %%
len(not_fixed_colors.unique())
# Out:
# 295

# %%
len(df["Color"].unique())
# Out:
# 223

# %%
unique_colors_before = not_fixed_colors.unique()
unique_colors_after = df["Color"].unique()

# %%
diff = len(unique_colors_before) - len(unique_colors_after)

tmp = list(unique_colors_after)
for i in range(diff):
    tmp.append(0)
    
unique_colors_after = np.asarray(tmp)

data = {
    "Before": unique_colors_before,
    "After": unique_colors_after
}

df_for_colors_check = pd.DataFrame(data)
df_for_colors_check
df_for_colors_check.to_csv("./test_data/test.csv")

# %%
df["Intake Condition"].unique()
# Out:
# array(['HEALTHY', 'TREATABLE/MANAGEABLE', 'TREATABLE/REHAB',
#        'UNTREATABLE'], dtype=object)

# %%
df = df.replace("TREATABLE/MANAGEABLE", "TREATABLE")
df = df.replace("TREATABLE/REHAB", "TREATABLE")

# %%
# df[df["Days in Shelter"].str.contains(",")]

# %%
# df['Days in Shelter'] = df['Days in Shelter'].str.replace(',', '')

# %%
# df[df["Days in Shelter"].str.contains(",")]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df["Days in Shelter"] = df["Days in Shelter"].astype(float)
sns.boxplot(x=df["Days in Shelter"])
plt.show()

# %%
df[df["Days in Shelter"] > 50].count()
# Out:
# Type                1723
# Breed               1723
# Color               1723
# Sex                 1723
# Size                1723
# Date Of Birth       1617
# Days in Shelter     1723
# Intake Type         1723
# Intake Subtype      1723
# Intake Condition    1723
# dtype: int64

# %%
df.drop(df[df["Days in Shelter"] > 50].index, inplace=True)
df
# Out:
#       Type              Breed            Color      Sex   Size Date Of Birth
# 9      CAT        DOMESTIC SH  BRN TABBY/WHITE     Male  SMALL    07/06/2018  \
# 24     CAT        DOMESTIC SH      BLACK/WHITE     Male  SMALL    01/12/2022
# 25     CAT        DOMESTIC SH           CALICO   Female  SMALL    04/10/2022
# 40     DOG      LABRADOR RETR            BROWN     Male  LARGE    06/28/2006
# 43     DOG  LABRADOR RETR/MIX            BLACK   Female  LARGE    10/31/2014
# ...    ...                ...              ...      ...    ...           ...
# 25427  CAT        DOMESTIC SH      BLACK/WHITE   Female  SMALL    05/12/2014
# 25429  DOG    AUST CATTLE DOG        BLACK/TAN  Unknown  SMALL    02/21/2022
# 25430  CAT        DOMESTIC SH       WHITE/GRAY     Male  SMALL    10/15/2017
# 25432  DOG           PIT BULL        TAN/WHITE     Male  LARGE    12/22/2012
# 25433  DOG   CHIHUAHUA SH/MIX      BROWN/WHITE     Male  SMALL    07/28/2011
#
#        Days in Shelter      Intake Type    Intake Subtype Intake Condition
# 9                  4.0            STRAY  OVER THE COUNTER          HEALTHY
# 24                45.0            STRAY  OVER THE COUNTER          HEALTHY
# 25                33.0  OWNER SURRENDER  OVER THE COUNTER          HEALTHY
# 40                 1.0            STRAY             FIELD          HEALTHY
# 43                 1.0            STRAY             FIELD          HEALTHY
# ...                ...              ...               ...              ...
# 25427              5.0            STRAY          COMM CAT          HEALTHY
# 25429              2.0            STRAY         BORN_HERE        TREATABLE
# 25430             20.0            STRAY  OVER THE COUNTER          HEALTHY
# 25432             21.0            STRAY  OVER THE COUNTER      UNTREATABLE
# 25433             49.0            STRAY             FIELD          HEALTHY
#
# [13515 rows x 10 columns]

# %%
sns.boxplot(x=df["Days in Shelter"])
plt.show()

# %%
df.isnull().sum()
# Out:
# Type                   0
# Breed                  0
# Color                  0
# Sex                    0
# Size                   0
# Date Of Birth       2458
# Days in Shelter        0
# Intake Type            0
# Intake Subtype         0
# Intake Condition       0
# dtype: int64

# %%
from datetime import datetime

df.dropna(subset=['Date Of Birth'], inplace=True)
current_year = datetime.now().year
df["Date Of Birth"] = pd.to_datetime(df["Date Of Birth"])
df['Age'] = (current_year - df['Date Of Birth'].dt.year.astype(int))
df.drop(['Date Of Birth'], axis=1, inplace=True)
df
# Out:
#       Type              Breed            Color      Sex   Size
# 9      CAT        DOMESTIC SH  BRN TABBY/WHITE     Male  SMALL  \
# 24     CAT        DOMESTIC SH      BLACK/WHITE     Male  SMALL
# 25     CAT        DOMESTIC SH           CALICO   Female  SMALL
# 40     DOG      LABRADOR RETR            BROWN     Male  LARGE
# 43     DOG  LABRADOR RETR/MIX            BLACK   Female  LARGE
# ...    ...                ...              ...      ...    ...
# 25427  CAT        DOMESTIC SH      BLACK/WHITE   Female  SMALL
# 25429  DOG    AUST CATTLE DOG        BLACK/TAN  Unknown  SMALL
# 25430  CAT        DOMESTIC SH       WHITE/GRAY     Male  SMALL
# 25432  DOG           PIT BULL        TAN/WHITE     Male  LARGE
# 25433  DOG   CHIHUAHUA SH/MIX      BROWN/WHITE     Male  SMALL
#
#        Days in Shelter      Intake Type    Intake Subtype Intake Condition
# 9                  4.0            STRAY  OVER THE COUNTER          HEALTHY  \
# 24                45.0            STRAY  OVER THE COUNTER          HEALTHY
# 25                33.0  OWNER SURRENDER  OVER THE COUNTER          HEALTHY
# 40                 1.0            STRAY             FIELD          HEALTHY
# 43                 1.0            STRAY             FIELD          HEALTHY
# ...                ...              ...               ...              ...
# 25427              5.0            STRAY          COMM CAT          HEALTHY
# 25429              2.0            STRAY         BORN_HERE        TREATABLE
# 25430             20.0            STRAY  OVER THE COUNTER          HEALTHY
# 25432             21.0            STRAY  OVER THE COUNTER      UNTREATABLE
# 25433             49.0            STRAY             FIELD          HEALTHY
#
#        Age
# 9        5
# 24       1
# 25       1
# 40      17
# 43       9
# ...    ...
# 25427    9
# 25429    1
# 25430    6
# 25432   11
# 25433   12
#
# [11057 rows x 10 columns]

# %%
sns.boxplot(x=df["Age"])
plt.show()

# %%
df.drop(df[df["Age"] > 20].index, inplace=True)
df
# Out:
#       Type              Breed            Color      Sex   Size
# 9      CAT        DOMESTIC SH  BRN TABBY/WHITE     Male  SMALL  \
# 24     CAT        DOMESTIC SH      BLACK/WHITE     Male  SMALL
# 25     CAT        DOMESTIC SH           CALICO   Female  SMALL
# 40     DOG      LABRADOR RETR            BROWN     Male  LARGE
# 43     DOG  LABRADOR RETR/MIX            BLACK   Female  LARGE
# ...    ...                ...              ...      ...    ...
# 25427  CAT        DOMESTIC SH      BLACK/WHITE   Female  SMALL
# 25429  DOG    AUST CATTLE DOG        BLACK/TAN  Unknown  SMALL
# 25430  CAT        DOMESTIC SH       WHITE/GRAY     Male  SMALL
# 25432  DOG           PIT BULL        TAN/WHITE     Male  LARGE
# 25433  DOG   CHIHUAHUA SH/MIX      BROWN/WHITE     Male  SMALL
#
#        Days in Shelter      Intake Type    Intake Subtype Intake Condition
# 9                  4.0            STRAY  OVER THE COUNTER          HEALTHY  \
# 24                45.0            STRAY  OVER THE COUNTER          HEALTHY
# 25                33.0  OWNER SURRENDER  OVER THE COUNTER          HEALTHY
# 40                 1.0            STRAY             FIELD          HEALTHY
# 43                 1.0            STRAY             FIELD          HEALTHY
# ...                ...              ...               ...              ...
# 25427              5.0            STRAY          COMM CAT          HEALTHY
# 25429              2.0            STRAY         BORN_HERE        TREATABLE
# 25430             20.0            STRAY  OVER THE COUNTER          HEALTHY
# 25432             21.0            STRAY  OVER THE COUNTER      UNTREATABLE
# 25433             49.0            STRAY             FIELD          HEALTHY
#
#        Age
# 9        5
# 24       1
# 25       1
# 40      17
# 43       9
# ...    ...
# 25427    9
# 25429    1
# 25430    6
# 25432   11
# 25433   12
#
# [10779 rows x 10 columns]

# %%
df
# Out:
#       Type              Breed            Color      Sex   Size
# 9      CAT        DOMESTIC SH  BRN TABBY/WHITE     Male  SMALL  \
# 24     CAT        DOMESTIC SH      BLACK/WHITE     Male  SMALL
# 25     CAT        DOMESTIC SH           CALICO   Female  SMALL
# 40     DOG      LABRADOR RETR            BROWN     Male  LARGE
# 43     DOG  LABRADOR RETR/MIX            BLACK   Female  LARGE
# ...    ...                ...              ...      ...    ...
# 25427  CAT        DOMESTIC SH      BLACK/WHITE   Female  SMALL
# 25429  DOG    AUST CATTLE DOG        BLACK/TAN  Unknown  SMALL
# 25430  CAT        DOMESTIC SH       WHITE/GRAY     Male  SMALL
# 25432  DOG           PIT BULL        TAN/WHITE     Male  LARGE
# 25433  DOG   CHIHUAHUA SH/MIX      BROWN/WHITE     Male  SMALL
#
#        Days in Shelter      Intake Type    Intake Subtype Intake Condition
# 9                  4.0            STRAY  OVER THE COUNTER          HEALTHY  \
# 24                45.0            STRAY  OVER THE COUNTER          HEALTHY
# 25                33.0  OWNER SURRENDER  OVER THE COUNTER          HEALTHY
# 40                 1.0            STRAY             FIELD          HEALTHY
# 43                 1.0            STRAY             FIELD          HEALTHY
# ...                ...              ...               ...              ...
# 25427              5.0            STRAY          COMM CAT          HEALTHY
# 25429              2.0            STRAY         BORN_HERE        TREATABLE
# 25430             20.0            STRAY  OVER THE COUNTER          HEALTHY
# 25432             21.0            STRAY  OVER THE COUNTER      UNTREATABLE
# 25433             49.0            STRAY             FIELD          HEALTHY
#
#        Age
# 9        5
# 24       1
# 25       1
# 40      17
# 43       9
# ...    ...
# 25427    9
# 25429    1
# 25430    6
# 25432   11
# 25433   12
#
# [10779 rows x 10 columns]

# %%
df.drop(df[df["Sex"] == "Unknown"].index, inplace=True)
df
# Out:
#       Type              Breed            Color     Sex    Size
# 9      CAT        DOMESTIC SH  BRN TABBY/WHITE    Male   SMALL  \
# 24     CAT        DOMESTIC SH      BLACK/WHITE    Male   SMALL
# 25     CAT        DOMESTIC SH           CALICO  Female   SMALL
# 40     DOG      LABRADOR RETR            BROWN    Male   LARGE
# 43     DOG  LABRADOR RETR/MIX            BLACK  Female   LARGE
# ...    ...                ...              ...     ...     ...
# 25426  DOG           PIT BULL       BLUE/WHITE  Female  MEDIUM
# 25427  CAT        DOMESTIC SH      BLACK/WHITE  Female   SMALL
# 25430  CAT        DOMESTIC SH       WHITE/GRAY    Male   SMALL
# 25432  DOG           PIT BULL        TAN/WHITE    Male   LARGE
# 25433  DOG   CHIHUAHUA SH/MIX      BROWN/WHITE    Male   SMALL
#
#        Days in Shelter      Intake Type    Intake Subtype Intake Condition
# 9                  4.0            STRAY  OVER THE COUNTER          HEALTHY  \
# 24                45.0            STRAY  OVER THE COUNTER          HEALTHY
# 25                33.0  OWNER SURRENDER  OVER THE COUNTER          HEALTHY
# 40                 1.0            STRAY             FIELD          HEALTHY
# 43                 1.0            STRAY             FIELD          HEALTHY
# ...                ...              ...               ...              ...
# 25426             16.0            STRAY             FIELD          HEALTHY
# 25427              5.0            STRAY          COMM CAT          HEALTHY
# 25430             20.0            STRAY  OVER THE COUNTER          HEALTHY
# 25432             21.0            STRAY  OVER THE COUNTER      UNTREATABLE
# 25433             49.0            STRAY             FIELD          HEALTHY
#
#        Age
# 9        5
# 24       1
# 25       1
# 40      17
# 43       9
# ...    ...
# 25426    8
# 25427    9
# 25430    6
# 25432   11
# 25433   12
#
# [10588 rows x 10 columns]

# %%
other_types = df[df["Type"] == "OTHER"]
other_types["Breed"].unique()
# Out:
# array(['PIG', 'GUINEA PIG', 'LOP-AMER FUZZY', 'HAMSTER', 'RABBIT SH',
#        'DWARF HOTOT', 'PARAKEET', 'SHETLAND', 'ENGLISH SPOT/MIX',
#        'HAVANA/MIX', 'POTBELLY PIG', 'RABBIT LH', 'JERSEY/MIX',
#        'LOP-MINI/MIX', 'REX', 'REX/MIX', 'GOAT', 'CHICKEN',
#        'CALIFORNIAN/MIX', 'RAT', 'LOP-MINI', 'LOP-FRENCH', 'SILVER',
#        'GOAT/LA MANCHA', 'AMERICAN/REX', 'RHINELANDER/MIX', 'HOTOT',
#        'SHEEP', 'ANGORA-ENGLISH', 'HARLEQUIN/MIX', 'DUTCH/MIX', 'BOER',
#        'HOTOT/MIX', 'NETHERLND DWARF/MIX', 'COCKATIEL', 'HIMALAYAN/MIX',
#        'DUTCH', 'PALOMINO', 'HORSE', 'LOP-ENGLISH/MIX',
#        'ANGORA-SATIN/MIX', 'LOP-HOLLAND', 'RACCOON', 'AMERICAN',
#        'LOP-HOLLAND/MIX', 'CALIFORNIAN', 'REX-MINI/MIX', 'LOP-ENGLISH',
#        'GOAT/ALPINE', 'PALOMINO/MIX', 'CANARY', 'DOVE', 'BARRED ROCK',
#        'LOP-AMER FUZZY/MIX', 'RABBIT LH/MIX', 'ENGLISH SPOT', 'MOUSE',
#        'GOAT/NUBIAN'], dtype=object)

# %%
df.loc[(df["Type"] == "OTHER") & (df["Breed"] == "PALOMINO/MIX"), "Breed"] = "PALOMINO"

# %%
other_types = df[df["Type"] == "OTHER"]
other_types["Breed"].unique()
# Out:
# array(['PIG', 'GUINEA PIG', 'LOP-AMER FUZZY', 'HAMSTER', 'RABBIT SH',
#        'DWARF HOTOT', 'PARAKEET', 'SHETLAND', 'ENGLISH SPOT/MIX',
#        'HAVANA/MIX', 'POTBELLY PIG', 'RABBIT LH', 'JERSEY/MIX',
#        'LOP-MINI/MIX', 'REX', 'REX/MIX', 'GOAT', 'CHICKEN',
#        'CALIFORNIAN/MIX', 'RAT', 'LOP-MINI', 'LOP-FRENCH', 'SILVER',
#        'GOAT/LA MANCHA', 'AMERICAN/REX', 'RHINELANDER/MIX', 'HOTOT',
#        'SHEEP', 'ANGORA-ENGLISH', 'HARLEQUIN/MIX', 'DUTCH/MIX', 'BOER',
#        'HOTOT/MIX', 'NETHERLND DWARF/MIX', 'COCKATIEL', 'HIMALAYAN/MIX',
#        'DUTCH', 'PALOMINO', 'HORSE', 'LOP-ENGLISH/MIX',
#        'ANGORA-SATIN/MIX', 'LOP-HOLLAND', 'RACCOON', 'AMERICAN',
#        'LOP-HOLLAND/MIX', 'CALIFORNIAN', 'REX-MINI/MIX', 'LOP-ENGLISH',
#        'GOAT/ALPINE', 'CANARY', 'DOVE', 'BARRED ROCK',
#        'LOP-AMER FUZZY/MIX', 'RABBIT LH/MIX', 'ENGLISH SPOT', 'MOUSE',
#        'GOAT/NUBIAN'], dtype=object)

# %%
df.loc[(df["Type"] == "OTHER") & (df["Breed"].str.contains("MIX")), "Breed"] = "MIX"

# %%
other_types = df[df["Type"] == "OTHER"]
other_types["Breed"].unique()
# Out:
# array(['PIG', 'GUINEA PIG', 'LOP-AMER FUZZY', 'HAMSTER', 'RABBIT SH',
#        'DWARF HOTOT', 'PARAKEET', 'SHETLAND', 'MIX', 'POTBELLY PIG',
#        'RABBIT LH', 'REX', 'GOAT', 'CHICKEN', 'RAT', 'LOP-MINI',
#        'LOP-FRENCH', 'SILVER', 'GOAT/LA MANCHA', 'AMERICAN/REX', 'HOTOT',
#        'SHEEP', 'ANGORA-ENGLISH', 'BOER', 'COCKATIEL', 'DUTCH',
#        'PALOMINO', 'HORSE', 'LOP-HOLLAND', 'RACCOON', 'AMERICAN',
#        'CALIFORNIAN', 'LOP-ENGLISH', 'GOAT/ALPINE', 'CANARY', 'DOVE',
#        'BARRED ROCK', 'ENGLISH SPOT', 'MOUSE', 'GOAT/NUBIAN'],
#       dtype=object)

# %%
df.loc[(df["Type"] == "OTHER") & (df["Breed"].str.contains("GOAT")), "Breed"] = "GOAT"

# %%
other_types = df[df["Type"] == "OTHER"]
other_types["Breed"].unique()
# Out:
# array(['PIG', 'GUINEA PIG', 'LOP-AMER FUZZY', 'HAMSTER', 'RABBIT SH',
#        'DWARF HOTOT', 'PARAKEET', 'SHETLAND', 'MIX', 'POTBELLY PIG',
#        'RABBIT LH', 'REX', 'GOAT', 'CHICKEN', 'RAT', 'LOP-MINI',
#        'LOP-FRENCH', 'SILVER', 'AMERICAN/REX', 'HOTOT', 'SHEEP',
#        'ANGORA-ENGLISH', 'BOER', 'COCKATIEL', 'DUTCH', 'PALOMINO',
#        'HORSE', 'LOP-HOLLAND', 'RACCOON', 'AMERICAN', 'CALIFORNIAN',
#        'LOP-ENGLISH', 'CANARY', 'DOVE', 'BARRED ROCK', 'ENGLISH SPOT',
#        'MOUSE'], dtype=object)

# %%
df.loc[(df["Type"] == "OTHER") & (df["Breed"] == "AMERICAN/REX"), "Breed"] = "MIX"

# %%
other_types = df[df["Type"] == "OTHER"]
other_types["Breed"].unique()
# Out:
# array(['PIG', 'GUINEA PIG', 'LOP-AMER FUZZY', 'HAMSTER', 'RABBIT SH',
#        'DWARF HOTOT', 'PARAKEET', 'SHETLAND', 'MIX', 'POTBELLY PIG',
#        'RABBIT LH', 'REX', 'GOAT', 'CHICKEN', 'RAT', 'LOP-MINI',
#        'LOP-FRENCH', 'SILVER', 'HOTOT', 'SHEEP', 'ANGORA-ENGLISH', 'BOER',
#        'COCKATIEL', 'DUTCH', 'PALOMINO', 'HORSE', 'LOP-HOLLAND',
#        'RACCOON', 'AMERICAN', 'CALIFORNIAN', 'LOP-ENGLISH', 'CANARY',
#        'DOVE', 'BARRED ROCK', 'ENGLISH SPOT', 'MOUSE'], dtype=object)

# %%
df.loc[(df["Type"] == "OTHER") & (df["Breed"].isin(["RABBIT SH", "RABBIT LH"])), "Breed"] = "RABBIT"

# %%
rabbit_breeds = ["LOP-AMER FUZZY",
                    "LOP-HOLLAND",
                    "RABBIT",
                    "DWARF HOTOT",
                    "MIX",
                    "REX",
                    "LOP-MINI",
                    "LOP-FRENCH",
                    "SILVER",
                    "HOTOT",
                    "ANGORA-ENGLISH",
                    "DUTCH",
                    "AMERICAN",
                    "CALIFORNIAN",
                    "LOP-ENGLISH",
                    "ENGLISH SPOT"]

df.loc[(df["Type"] == "OTHER") & (df["Breed"].isin(rabbit_breeds)), "Breed"] = "RABBIT"

roden_breeds = ["GUINEA PIG",
                "HAMSTER",
                "RAT",
                "MOUSE"]

df.loc[(df["Type"] == "OTHER") & (df["Breed"].isin(roden_breeds)), "Breed"] = "RODENT"

live_stock_breeds = ["GOAT",
                    "CHICKEN",
                    "SHEEP",
                    "BOER",
                    "BARRED ROCK"]

df.loc[(df["Type"] == "OTHER") & (df["Breed"].isin(live_stock_breeds)), "Breed"] = "LIVESTOCK"

bird_breeds = ["PARAKEET",
                "COCKATIEL",
                "CANARY",
                "DOVE"]

df.loc[(df["Type"] == "OTHER") & (df["Breed"].isin(bird_breeds)), "Breed"] = "BIRD"

horse_breeds = ["HORSE",
                "SHETLAND",
                "PALOMINO"]

df.loc[(df["Type"] == "OTHER") & (df["Breed"].isin(horse_breeds)), "Breed"] = "HORSE"

if "RACCOON" in df["Breed"].values:
    df.loc[df["Breed"] == "RACCOON", "Type"] = "RACCOON"

# %%
dog_types = df[df["Type"] == "DOG"]
sorted(dog_types["Breed"].unique())
# Out:
# ['AFFENPINSCHER',
#  'AIREDALE TERR',
#  'AIREDALE TERR/MIX',
#  'AKBASH',
#  'AKBASH/MIX',
#  'AKITA',
#  'AKITA/ALASKAN HUSKY',
#  'AKITA/GERM SHEPHERD',
#  'AKITA/LABRADOR RETR',
#  'AKITA/MIX',
#  'ALASK KLEE KAI',
#  'ALASK MALAMUTE',
#  'ALASKAN HUSKY',
#  'ALASKAN HUSKY/AUST SHEPHERD',
#  'ALASKAN HUSKY/BEAGLE',
#  'ALASKAN HUSKY/BORDER COLLIE',
#  'ALASKAN HUSKY/GERM SHEPHERD',
#  'ALASKAN HUSKY/LABRADOR RETR',
#  'ALASKAN HUSKY/MIX',
#  'ALASKAN HUSKY/PIT BULL',
#  'ALASKAN HUSKY/SHIBA INU',
#  'AM PIT BULL TER',
#  'AM PIT BULL TER/MIX',
#  'AMER BULLDOG',
#  'AMER BULLDOG/BOXER',
#  'AMER BULLDOG/MIX',
#  'AMER BULLDOG/PIT BULL',
#  'AMER ESKIMO',
#  'AMER ESKIMO/MIX',
#  'AMER FOXHOUND',
#  'AMER FOXHOUND/GREAT PYRENEES',
#  'AMER FOXHOUND/WHIPPET',
#  'AMERICAN STAFF',
#  'AMERICAN STAFF/CHIHUAHUA SH',
#  'AMERICAN STAFF/GERM SHEPHERD',
#  'AMERICAN STAFF/MIX',
#  'AMERICAN STAFF/PIT BULL',
#  'ANATOL SHEPHERD',
#  'ANATOL SHEPHERD/MIX',
#  'AUST CATTLE DOG',
#  'AUST CATTLE DOG/BELG MALINOIS',
#  'AUST CATTLE DOG/BORDER COLLIE',
#  'AUST CATTLE DOG/CATAHOULA',
#  'AUST CATTLE DOG/LABRADOR RETR',
#  'AUST CATTLE DOG/MIX',
#  'AUST CATTLE DOG/PARSON RUSS TER',
#  'AUST CATTLE DOG/QUEENSLAND HEEL',
#  'AUST KELPIE',
#  'AUST KELPIE/BORDER COLLIE',
#  'AUST KELPIE/CATAHOULA',
#  'AUST KELPIE/GERM SHEPHERD',
#  'AUST KELPIE/MIX',
#  'AUST KELPIE/PIT BULL',
#  'AUST SHEPHERD',
#  'AUST SHEPHERD/BORDER COLLIE',
#  'AUST SHEPHERD/CHIHUAHUA SH',
#  'AUST SHEPHERD/GERM SHEPHERD',
#  'AUST SHEPHERD/GOLDEN RETR',
#  'AUST SHEPHERD/LABRADOR RETR',
#  'AUST SHEPHERD/MIX',
#  'AUST SHEPHERD/PIT BULL',
#  'AUST SHEPHERD/WOLF',
#  'AUST TERRIER',
#  'AUST TERRIER/MIX',
#  'AUST TERRIER/YORKSHIRE TERR',
#  'BASENJI/MIX',
#  'BASSET HOUND',
#  'BASSET HOUND/MIX',
#  'BASSET HOUND/PIT BULL',
#  'BEAGLE',
#  'BEAGLE/AMERICAN STAFF',
#  'BEAGLE/CHIHUAHUA SH',
#  'BEAGLE/FOX TERR SMOOTH',
#  'BEAGLE/FOX TERR WIRE',
#  'BEAGLE/GERM SHEPHERD',
#  'BEAGLE/MIX',
#  'BEAGLE/PARSON RUSS TER',
#  'BEAGLE/PUG',
#  'BEAGLE/RAT TERRIER',
#  'BEAGLE/TOY FOX TERRIER',
#  'BEAGLE/WELSH CORGI PEM',
#  'BEARDED COLLIE/MIX',
#  'BELG MALINOIS',
#  'BELG MALINOIS/GERM SHEPHERD',
#  'BELG MALINOIS/MIX',
#  'BELG TERVUREN/GERM SHEPHERD',
#  'BELG TERVUREN/MIX',
#  'BICHON FRISE',
#  'BICHON FRISE/CAVALIER SPAN',
#  'BICHON FRISE/MIX',
#  'BICHON FRISE/POODLE MIN',
#  'BICHON FRISE/WEST HIGHLAND',
#  'BLACK MOUTH CUR',
#  'BLACK MOUTH CUR/CATAHOULA',
#  'BLACK MOUTH CUR/MIX',
#  'BLACK/TAN HOUND',
#  'BLACK/TAN HOUND/MIX',
#  'BLOODHOUND',
#  'BLOODHOUND/GERM SHEPHERD',
#  'BLUETICK HOUND',
#  'BLUETICK HOUND/MIX',
#  'BOERBOEL',
#  'BORDER COLLIE',
#  'BORDER COLLIE X',
#  'BORDER COLLIE/ALASKAN HUSKY',
#  'BORDER COLLIE/AUST CATTLE DOG',
#  'BORDER COLLIE/AUST KELPIE',
#  'BORDER COLLIE/BASENJI',
#  'BORDER COLLIE/BLACK/TAN HOUND',
#  'BORDER COLLIE/BOXER',
#  'BORDER COLLIE/CATAHOULA',
#  'BORDER COLLIE/GERM SHEPHERD',
#  'BORDER COLLIE/GREAT PYRENEES',
#  'BORDER COLLIE/LABRADOR RETR',
#  'BORDER COLLIE/MIX',
#  'BORDER COLLIE/NEWFOUNDLAND',
#  'BORDER COLLIE/PARSON RUSS TER',
#  'BORDER COLLIE/PIT BULL',
#  'BORDER COLLIE/SIBERIAN HUSKY',
#  'BORDER TERRIER/MIX',
#  'BOSTON TERRIER',
#  'BOSTON TERRIER/MIX',
#  'BOSTON TERRIER/PIT BULL',
#  'BOSTON TERRIER/RAT TERRIER',
#  'BOXER',
#  'BOXER/ENG FOXHOUND',
#  'BOXER/LABRADOR RETR',
#  'BOXER/MIX',
#  'BOXER/PIT BULL',
#  'BOXER/QUEENSLAND HEEL',
#  'BOXER/RHOD RIDGEBACK',
#  'BRITTANY',
#  'BRITTANY/MIX',
#  'BRUSS GRIFFON',
#  'BRUSS GRIFFON/CHIHUAHUA SH',
#  'BRUSS GRIFFON/MIX',
#  'BULL TERRIER',
#  'BULL TERRIER/BORDER COLLIE',
#  'BULL TERRIER/LABRADOR RETR',
#  'BULL TERRIER/MIX',
#  'BULL TERRIER/PARSON RUSS TER',
#  'BULL TERRIER/WELSH CORGI CAR',
#  'BULLDOG',
#  'BULLDOG/MIX',
#  'BULLDOG/PIT BULL',
#  'BULLMASTIFF',
#  'BULLMASTIFF/MIX',
#  'CAIRN TERRIER',
#  'CAIRN TERRIER/CHIHUAHUA SH',
#  'CAIRN TERRIER/MIX',
#  'CAIRN TERRIER/POMERANIAN',
#  'CAIRN TERRIER/POODLE MIN',
#  'CAIRN TERRIER/PUG',
#  'CAIRN TERRIER/SCHNAUZER MIN',
#  'CAIRN TERRIER/SKYE TERRIER',
#  'CANE CORSO',
#  'CANE CORSO/MASTIFF',
#  'CAROLINA DOG',
#  'CAROLINA DOG/GERM SHEPHERD',
#  'CATAHOULA',
#  'CATAHOULA/AM PIT BULL TER',
#  'CATAHOULA/BLACK MOUTH CUR',
#  'CATAHOULA/BORDER COLLIE',
#  'CATAHOULA/BULLDOG',
#  'CATAHOULA/GREYHOUND',
#  'CATAHOULA/LABRADOR RETR',
#  'CATAHOULA/MIX',
#  'CATAHOULA/PLOTT HOUND',
#  'CATAHOULA/ROTTWEILER',
#  'CATAHOULA/SALUKI',
#  'CAVALIER SPAN',
#  'CAVALIER SPAN/CHIHUAHUA LH',
#  'CAVALIER SPAN/MIX',
#  'CHESA BAY RETR',
#  'CHIHUAHUA LH',
#  'CHIHUAHUA LH/DACHSHUND LH',
#  'CHIHUAHUA LH/FOX TERR WIRE',
#  'CHIHUAHUA LH/MIX',
#  'CHIHUAHUA LH/NORFOLK TERRIER',
#  'CHIHUAHUA LH/PAPILLON',
#  'CHIHUAHUA LH/PARSON RUSS TER',
#  'CHIHUAHUA LH/POMERANIAN',
#  'CHIHUAHUA LH/POODLE MIN',
#  'CHIHUAHUA LH/SHIBA INU',
#  'CHIHUAHUA LH/SHIH TZU',
#  'CHIHUAHUA LH/WELSH CORGI PEM',
#  'CHIHUAHUA LH/YORKSHIRE TERR',
#  'CHIHUAHUA SH',
#  'CHIHUAHUA SH/BEAGLE',
#  'CHIHUAHUA SH/CAIRN TERRIER',
#  'CHIHUAHUA SH/DACHSHUND',
#  'CHIHUAHUA SH/FOX TERR SMOOTH',
#  'CHIHUAHUA SH/MALTESE',
#  'CHIHUAHUA SH/MIN PINSCHER',
#  'CHIHUAHUA SH/MIX',
#  'CHIHUAHUA SH/PARSON RUSS TER',
#  'CHIHUAHUA SH/PIT BULL',
#  'CHIHUAHUA SH/POMERANIAN',
#  'CHIHUAHUA SH/POODLE MIN',
#  'CHIHUAHUA SH/PUG',
#  'CHIHUAHUA SH/RAT TERRIER',
#  'CHIHUAHUA SH/SCOT TERRIER',
#  'CHIHUAHUA SH/SHETLD SHEEPDOG',
#  'CHIHUAHUA SH/SHIBA INU',
#  'CHIHUAHUA SH/SHIH TZU',
#  'CHIHUAHUA SH/TERRIER',
#  'CHIHUAHUA SH/YORKSHIRE TERR',
#  'CHIHUAHUA X',
#  'CHINESE CRESTED',
#  'CHINESE SHARPEI',
#  'CHINESE SHARPEI/BEAGLE',
#  'CHINESE SHARPEI/CHIHUAHUA SH',
#  'CHINESE SHARPEI/MIX',
#  'CHINESE SHARPEI/PIT BULL',
#  'CHINESE SHARPEI/WELSH CORGI PEM',
#  'CHOW CHOW',
#  'CHOW CHOW/MIX',
#  'COCKER SPAN',
#  'COCKER SPAN/CHIHUAHUA LH',
#  'COCKER SPAN/CHIHUAHUA SH',
#  'COCKER SPAN/MIX',
#  'COCKER SPAN/POODLE MIN',
#  'COLLIE ROUGH',
#  'COLLIE ROUGH/GERM SHEPHERD',
#  'COLLIE ROUGH/MIX',
#  'COLLIE SMOOTH/CHOW CHOW',
#  'COLLIE SMOOTH/MIX',
#  'COTON DE TULEAR',
#  'DACHSHUND',
#  'DACHSHUND LH',
#  'DACHSHUND LH/MIX',
#  'DACHSHUND WH',
#  'DACHSHUND WH/CAIRN TERRIER',
#  'DACHSHUND WH/CHIHUAHUA SH',
#  'DACHSHUND WH/MIX',
#  'DACHSHUND/AUST CATTLE DOG',
#  'DACHSHUND/CHIHUAHUA SH',
#  'DACHSHUND/COLLIE ROUGH',
#  'DACHSHUND/MIX',
#  'DACHSHUND/PARSON RUSS TER',
#  'DACHSHUND/POMERANIAN',
#  'DACHSHUND/POODLE MIN',
#  'DACHSHUND/WELSH CORGI CAR',
#  'DALMATIAN/MIX',
#  'DOBERMAN PINSCH',
#  'DOBERMAN PINSCH/AUST KELPIE',
#  'DOBERMAN PINSCH/ENG COONHOUND',
#  'DOBERMAN PINSCH/GERM SHEPHERD',
#  'DOBERMAN PINSCH/MIX',
#  'DOGO ARGENTINO',
#  'DOGUE DE BORDX',
#  'DUTCH SHEPHERD',
#  'DUTCH SHEPHERD/MIX',
#  'DUTCH SHEPHERD/ROTTWEILER',
#  'ENG BULLDOG',
#  'ENG BULLDOG/FRENCH BULLDOG',
#  'ENG COONHOUND',
#  'ENG COONHOUND/MIX',
#  'ENG FOXHOUND/MIX',
#  'ENG POINTER',
#  'ENG SETTER',
#  'ENG SPRNGR SPAN',
#  'ENG SPRNGR SPAN/MIX',
#  'ENG TOY SPANIEL',
#  'FLAT COAT RETR/GERM SHEPHERD',
#  'FLAT COAT RETR/MIX',
#  'FOX TERR SMOOTH',
#  'FOX TERR SMOOTH/BEAGLE',
#  'FOX TERR SMOOTH/BORDER COLLIE',
#  'FOX TERR SMOOTH/CAVALIER SPAN',
#  'FOX TERR SMOOTH/CHIHUAHUA SH',
#  'FOX TERR SMOOTH/MIX',
#  'FOX TERR WIRE',
#  'FOX TERR WIRE/MIX',
#  'FOX TERR WIRE/PIT BULL',
#  'FOX TERR WIRE/SHIH TZU',
#  'FRENCH BULLDOG',
#  'FRENCH BULLDOG/CHIHUAHUA SH',
#  'FRENCH BULLDOG/MIX',
#  'GERM SH POINT',
#  'GERM SH POINT/MIX',
#  'GERM SH POINT/PIT BULL',
#  'GERM SHEPHERD',
#  'GERM SHEPHERD/ALASKAN HUSKY',
#  'GERM SHEPHERD/AMERICAN STAFF',
#  'GERM SHEPHERD/AUST CATTLE DOG',
#  'GERM SHEPHERD/AUST KELPIE',
#  'GERM SHEPHERD/BEAGLE',
#  'GERM SHEPHERD/BELG MALINOIS',
#  'GERM SHEPHERD/BLACK/TAN HOUND',
#  'GERM SHEPHERD/BORDER COLLIE',
#  'GERM SHEPHERD/CHOW CHOW',
#  'GERM SHEPHERD/DOBERMAN PINSCH',
#  'GERM SHEPHERD/GREAT PYRENEES',
#  'GERM SHEPHERD/LABRADOR RETR',
#  'GERM SHEPHERD/MASTIFF',
#  'GERM SHEPHERD/MIX',
#  'GERM SHEPHERD/PIT BULL',
#  'GERM SHEPHERD/POINTER',
#  'GERM SHEPHERD/QUEENSLAND HEEL',
#  'GERM SHEPHERD/ROTTWEILER',
#  'GERM SHEPHERD/SIBERIAN HUSKY',
#  'GERM SHEPHERD/STAFFORDSHIRE',
#  'GERM SHEPHERD/WELSH CORGI CAR',
#  'GERM SHEPHERD/WELSH CORGI PEM',
#  'GERM WH POINT',
#  'GERM WH POINT/LABRADOR RETR',
#  'GERM WH POINT/MIX',
#  'GOLDEN RETR',
#  'GOLDEN RETR/AUST CATTLE DOG',
#  'GOLDEN RETR/CHINESE SHARPEI',
#  'GOLDEN RETR/GERM SHEPHERD',
#  'GOLDEN RETR/MIX',
#  'GR SWISS MTN/MIX',
#  'GREAT DANE',
#  'GREAT DANE/LABRADOR RETR',
#  'GREAT DANE/MIX',
#  'GREAT PYRENEES',
#  'GREAT PYRENEES/AKBASH',
#  'GREAT PYRENEES/CATAHOULA',
#  'GREAT PYRENEES/LABRADOR RETR',
#  'GREAT PYRENEES/MIX',
#  'HARRIER/MIX',
#  'HAVANESE',
#  'HAVANESE/MIX',
#  'ITAL GREYHOUND',
#  'ITAL GREYHOUND/CHIHUAHUA SH',
#  'ITAL GREYHOUND/MIN PINSCHER',
#  'JACK/FOX TERR SMOOTH',
#  'JACK/MIX',
#  'JAPANESE CHIN/CHIHUAHUA LH',
#  'KOMONDOR',
#  'LABRADOR RETR',
#  'LABRADOR RETR/AKITA',
#  'LABRADOR RETR/AM PIT BULL TER',
#  'LABRADOR RETR/AMERICAN STAFF',
#  'LABRADOR RETR/BELG MALINOIS',
#  'LABRADOR RETR/BORDER COLLIE',
#  'LABRADOR RETR/BOSTON TERRIER',
#  'LABRADOR RETR/BOXER',
#  'LABRADOR RETR/CANE CORSO',
#  'LABRADOR RETR/CATAHOULA',
#  'LABRADOR RETR/CHINESE SHARPEI',
#  'LABRADOR RETR/CHOW CHOW',
#  'LABRADOR RETR/DOBERMAN PINSCH',
#  'LABRADOR RETR/FLAT COAT RETR',
#  'LABRADOR RETR/GERM SHEPHERD',
#  'LABRADOR RETR/GREAT PYRENEES',
#  'LABRADOR RETR/MALTESE',
#  'LABRADOR RETR/MIX',
#  'LABRADOR RETR/PIT BULL',
#  'LABRADOR RETR/POINTER',
#  'LABRADOR RETR/POODLE STND',
#  'LABRADOR RETR/QUEENSLAND HEEL',
#  'LABRADOR RETR/ROTTWEILER',
#  'LABRADOR RETR/SIBERIAN HUSKY',
#  'LABRADOR RETR/VIZSLA',
#  'LEONBERGER/MIX',
#  'LHASA APSO',
#  'LHASA APSO/CAIRN TERRIER',
#  'LHASA APSO/CHIHUAHUA SH',
#  'LHASA APSO/MIX',
#  'LHASA APSO/PAPILLON',
#  'MALTESE',
#  'MALTESE/BICHON FRISE',
#  'MALTESE/FOX TERR SMOOTH',
#  'MALTESE/MIX',
#  'MALTESE/POODLE MIN',
#  'MALTESE/POODLE TOY',
#  'MALTESE/SHIH TZU',
#  'MALTESE/YORKSHIRE TERR',
#  'MANCHESTER TERR/MIX',
#  'MAREMMA SHEEPDG',
#  'MASTIFF',
#  'MASTIFF/BOXER',
#  'MASTIFF/GREAT DANE',
#  'MASTIFF/MIX',
#  'MASTIFF/PIT BULL',
#  'MASTIFF/QUEENSLAND HEEL',
#  'MASTIFF/REDBONE HOUND',
#  'MASTIFF/ST BERNARD RGH',
#  'MIN PINSCHER',
#  'MIN PINSCHER/CHIHUAHUA SH',
#  'MIN PINSCHER/MIX',
#  'MIN PINSCHER/PUG',
#  'MIX',
#  'NEWFOUNDLAND/MIX',
#  'NORFOLK TERRIER/MIX',
#  'NORW ELKHOUND',
#  'NORWICH TERRIER/CAIRN TERRIER',
#  'NORWICH TERRIER/MIX',
#  'OLD ENG BULLDOG/PIT BULL',
#  'PAPILLON',
#  'PAPILLON/CHIHUAHUA LH',
#  'PAPILLON/MIX',
#  'PAPILLON/PARSON RUSS TER',
#  'PARSON RUSS TER',
#  'PARSON RUSS TER/BEAGLE',
#  'PARSON RUSS TER/BORDER COLLIE',
#  'PARSON RUSS TER/BOSTON TERRIER',
#  'PARSON RUSS TER/BOXER',
#  'PARSON RUSS TER/CHIHUAHUA SH',
#  'PARSON RUSS TER/COCKER SPAN',
#  'PARSON RUSS TER/DACHSHUND',
#  'PARSON RUSS TER/DACHSHUND WH',
#  'PARSON RUSS TER/LABRADOR RETR',
#  'PARSON RUSS TER/MIX',
#  'PARSON RUSS TER/PAPILLON',
#  'PARSON RUSS TER/PIT BULL',
#  'PARSON RUSS TER/POMERANIAN',
#  'PARSON RUSS TER/SHIH TZU',
#  'PARSON RUSS TER/TIBETAN TERR',
#  'PATTERDALE TERR',
#  'PATTERDALE TERR/MIX',
#  'PBGV/MIX',
#  'PEKINGESE/CHIHUAHUA SH',
#  'PEKINGESE/MIX',
#  'PIT BULL',
#  'PIT BULL/AMERICAN STAFF',
#  'PIT BULL/AUST CATTLE DOG',
#  'PIT BULL/AUST KELPIE',
#  'PIT BULL/BASSET HOUND',
#  'PIT BULL/BEAGLE',
#  'PIT BULL/BORDER COLLIE',
#  'PIT BULL/BOSTON TERRIER',
#  'PIT BULL/BOXER',
#  'PIT BULL/BULL TERR MIN',
#  'PIT BULL/BULLMASTIFF',
#  'PIT BULL/CATAHOULA',
#  'PIT BULL/CHINESE SHARPEI',
#  'PIT BULL/DALMATIAN',
#  'PIT BULL/GERM SH POINT',
#  'PIT BULL/GERM SHEPHERD',
#  'PIT BULL/LABRADOR RETR',
#  'PIT BULL/MIX',
#  'PIT BULL/PARSON RUSS TER',
#  'PIT BULL/PEKINGESE',
#  'PIT BULL/RHOD RIDGEBACK',
#  'PIT BULL/ROTTWEILER',
#  'PIT BULL/SIBERIAN HUSKY',
#  'PIT BULL/WEIMARANER',
#  'PIT BULL/WELSH CORGI PEM',
#  'PITT BULL & LAB',
#  'PLOTT HOUND',
#  'PLOTT HOUND/MIX',
#  'PODENGO PEQUENO',
#  'POINTER/COCKER SPAN',
#  'POINTER/MIX',
#  'POMERANIAN',
#  'POMERANIAN/CHIHUAHUA SH',
#  'POMERANIAN/ITAL GREYHOUND',
#  'POMERANIAN/MIX',
#  'POMERANIAN/PEKINGESE',
#  'POMERANIAN/POODLE MIN',
#  'POMERANIAN/PUG',
#  'POMERANIAN/SCHIPPERKE',
#  'POMERANIAN/SHETLD SHEEPDOG',
#  'POMERANIAN/SIBERIAN HUSKY',
#  'POMERANIAN/YORKSHIRE TERR',
#  'POODLE MIN',
#  'POODLE MIN/BICHON FRISE',
#  'POODLE MIN/CAIRN TERRIER',
#  'POODLE MIN/COCKER SPAN',
#  'POODLE MIN/LABRADOR RETR',
#  'POODLE MIN/LHASA APSO',
#  'POODLE MIN/MALTESE',
#  'POODLE MIN/MIX',
#  'POODLE MIN/SHIH TZU',
#  'POODLE MIN/WEST HIGHLAND',
#  'POODLE MIN/YORKSHIRE TERR',
#  'POODLE STND',
#  'POODLE STND/LABRADOR RETR',
#  'POODLE STND/MIX',
#  'POODLE STND/WELSH TERRIER',
#  'POODLE TOY',
#  'POODLE TOY/CAIRN TERRIER',
#  'POODLE TOY/MALTESE',
#  'POODLE TOY/MIX',
#  'PRESA CANARIO',
#  'PUG',
#  'PUG/BEAGLE',
#  'PUG/CHIHUAHUA SH',
#  'PUG/MIX',
#  'QUEENSLAND HEEL',
#  'QUEENSLAND HEEL/AUST SHEPHERD',
#  'QUEENSLAND HEEL/MIX',
#  'QUEENSLAND HEEL/SIBERIAN HUSKY',
#  'RAT TERRIER',
#  'RAT TERRIER/AUST CATTLE DOG',
#  'RAT TERRIER/CHIHUAHUA SH',
#  'RAT TERRIER/DACHSHUND',
#  'RAT TERRIER/FOX TERR SMOOTH',
#  'RAT TERRIER/MIX',
#  'RAT TERRIER/SHETLD SHEEPDOG',
#  'REDBONE HOUND',
#  'REDBONE HOUND/MASTIFF',
#  'REDBONE HOUND/MIX',
#  'RHOD RIDGEBACK',
#  'RHOD RIDGEBACK/AM PIT BULL TER',
#  'RHOD RIDGEBACK/BOXER',
#  'RHOD RIDGEBACK/LABRADOR RETR',
#  'RHOD RIDGEBACK/MIX',
#  'ROTTWEILER',
#  'ROTTWEILER/AKITA',
#  'ROTTWEILER/ALASKAN HUSKY',
#  'ROTTWEILER/AUST SHEPHERD',
#  'ROTTWEILER/BOXER',
#  'ROTTWEILER/GERM SHEPHERD',
#  'ROTTWEILER/LABRADOR RETR',
#  'ROTTWEILER/MIX',
#  'SALUKI/MIX',
#  'SAMOYED',
#  'SAMOYED/MIX',
#  'SAMOYED/SIBERIAN HUSKY',
#  'SC WHEAT TERR',
#  'SC WHEAT TERR/MIX',
#  'SCHIPPERKE/MIX',
#  'SCHNAUZER MIN',
#  'SCHNAUZER MIN/DACHSHUND',
#  'SCHNAUZER MIN/MIX',
#  'SCHNAUZER STAND',
#  'SCHNAUZER STAND/MIX',
#  'SCOT DEERHOUND/MIX',
#  'SCOT TERRIER',
#  'SHETLD SHEEPDOG',
#  'SHETLD SHEEPDOG/BORDER COLLIE',
#  'SHETLD SHEEPDOG/MIX',
#  'SHETLD SHEEPDOG/PUG',
#  'SHETLD SHEEPDOG/WELSH CORGI CAR',
#  'SHIBA INU',
#  'SHIBA INU/MIX',
#  'SHIH TZU',
#  'SHIH TZU/CHIHUAHUA LH',
#  'SHIH TZU/LHASA APSO',
#  'SHIH TZU/MIX',
#  'SHIH TZU/PARSON RUSS TER',
#  'SHIH TZU/POODLE MIN',
#  'SHIH TZU/POODLE TOY',
#  'SIBERIAN HUSKY',
#  'SIBERIAN HUSKY/AIREDALE TERR',
#  'SIBERIAN HUSKY/AKITA',
#  'SIBERIAN HUSKY/ALASK MALAMUTE',
#  'SIBERIAN HUSKY/AUST CATTLE DOG',
#  'SIBERIAN HUSKY/AUST SHEPHERD',
#  'SIBERIAN HUSKY/BOXER',
#  'SIBERIAN HUSKY/CATAHOULA',
#  'SIBERIAN HUSKY/GERM SHEPHERD',
#  'SIBERIAN HUSKY/LABRADOR RETR',
#  'SIBERIAN HUSKY/MIX',
#  'SIBERIAN HUSKY/PIT BULL',
#  'SIBERIAN HUSKY/SIBERIAN HUSKY',
#  'SILKY TERRIER',
#  'SILKY TERRIER/MIX',
#  'SPANISH MASTIFF',
#  'ST BERNARD RGH',
#  'STAFFORDSHIRE',
#  'STAFFORDSHIRE/MIX',
#  'TIBETAN SPAN/CHIHUAHUA LH',
#  'TIBETAN TERR',
#  'TIBETAN TERR/MIX',
#  'TIBETAN TERR/WELSH CORGI CAR',
#  'TOSA/MIX',
#  'TOY FOX TERRIER',
#  'TOY FOX TERRIER/CHIHUAHUA SH',
#  'TOY FOX TERRIER/DACHSHUND',
#  'TOY FOX TERRIER/MIX',
#  'TR WALKER HOUND',
#  'TR WALKER HOUND/MIX',
#  'TR WALKER HOUND/PIT BULL',
#  'VIZSLA/LABRADOR RETR',
#  'VIZSLA/MIX',
#  'WEIMARANER',
#  'WELSH CORGI CAR',
#  'WELSH CORGI CAR/MIX',
#  'WELSH CORGI PEM',
#  'WELSH CORGI PEM/BORDER COLLIE',
#  'WELSH CORGI PEM/CAVALIER SPAN',
#  'WELSH CORGI PEM/MIX',
#  'WELSH CORGI PEM/QUEENSLAND HEEL',
#  'WELSH TERRIER/MIX',
#  'WEST HIGHLAND',
#  'WEST HIGHLAND/CHIHUAHUA SH',
#  'WEST HIGHLAND/MIX',
#  'WEST HIGHLAND/POODLE MIN',
#  'WHIPPET',
#  'WHIPPET/MIX',
#  'YORKSHIRE TERR',
#  'YORKSHIRE TERR/BRUSS GRIFFON',
#  'YORKSHIRE TERR/CAVALIER SPAN',
#  'YORKSHIRE TERR/CHIHUAHUA LH',
#  'YORKSHIRE TERR/FOX TERR WIRE',
#  'YORKSHIRE TERR/LHASA APSO',
#  'YORKSHIRE TERR/MALTESE',
#  'YORKSHIRE TERR/MIX',
#  'YORKSHIRE TERR/POODLE TOY',
#  'YORKSHIRE TERR/SCHNAUZER MIN']

# %%
len(dog_types["Breed"].unique())
# Out:
# 596

# %%
df.loc[(df["Type"] == "DOG") & (df["Breed"].str.contains("/")), "Breed"] = "MIX"

# %%
dog_types = df[df["Type"] == "DOG"]
len(dog_types["Breed"].unique())
# Out:
# 122

# %%
decision = df["Days in Shelter"]
attributes = df.drop("Days in Shelter", axis=1)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

attributes = pd.get_dummies(attributes).astype(int)

# %%
attributes
# Out:
#        Age  Type_CAT  Type_DOG  Type_OTHER  Type_RACCOON  Breed_ABYSSINIAN
# 9        5         1         0           0             0                 0  \
# 24       1         1         0           0             0                 0
# 25       1         1         0           0             0                 0
# 40      17         0         1           0             0                 0
# 43       9         0         1           0             0                 0
# ...    ...       ...       ...         ...           ...               ...
# 25426    8         0         1           0             0                 0
# 25427    9         1         0           0             0                 0
# 25430    6         1         0           0             0                 0
# 25432   11         0         1           0             0                 0
# 25433   12         0         1           0             0                 0
#
#        Breed_ABYSSINIAN/MIX  Breed_AFFENPINSCHER  Breed_AIREDALE TERR
# 9                         0                    0                    0  \
# 24                        0                    0                    0
# 25                        0                    0                    0
# 40                        0                    0                    0
# 43                        0                    0                    0
# ...                     ...                  ...                  ...
# 25426                     0                    0                    0
# 25427                     0                    0                    0
# 25430                     0                    0                    0
# 25432                     0                    0                    0
# 25433                     0                    0                    0
#
#        Breed_AKBASH  ...  Intake Subtype_OVER THE COUNTER_OWNED
# 9                 0  ...                                      0  \
# 24                0  ...                                      0
# 25                0  ...                                      0
# 40                0  ...                                      0
# 43                0  ...                                      0
# ...             ...  ...                                    ...
# 25426             0  ...                                      0
# 25427             0  ...                                      0
# 25430             0  ...                                      0
# 25432             0  ...                                      0
# 25433             0  ...                                      0
#
#        Intake Subtype_OVER THE COUNTER_RETURN TO OWNER
# 9                                                    0  \
# 24                                                   0
# 25                                                   0
# 40                                                   0
# 43                                                   0
# ...                                                ...
# 25426                                                0
# 25427                                                0
# 25430                                                0
# 25432                                                0
# 25433                                                0
#
#        Intake Subtype_OVER THE COUNTER_STRAY  Intake Subtype_PHONE
# 9                                          0                     0  \
# 24                                         0                     0
# 25                                         0                     0
# 40                                         0                     0
# 43                                         0                     0
# ...                                      ...                   ...
# 25426                                      0                     0
# 25427                                      0                     0
# 25430                                      0                     0
# 25432                                      0                     0
# 25433                                      0                     0
#
#        Intake Subtype_PRIV_SHELT  Intake Subtype_RESCUE_GRP
# 9                              0                          0  \
# 24                             0                          0
# 25                             0                          0
# 40                             0                          0
# 43                             0                          0
# ...                          ...                        ...
# 25426                          0                          0
# 25427                          0                          0
# 25430                          0                          0
# 25432                          0                          0
# 25433                          0                          0
#
#        Intake Subtype_VET_HOSP  Intake Condition_HEALTHY
# 9                            0                         1  \
# 24                           0                         1
# 25                           0                         1
# 40                           0                         1
# 43                           0                         1
# ...                        ...                       ...
# 25426                        0                         1
# 25427                        0                         1
# 25430                        0                         1
# 25432                        0                         0
# 25433                        0                         1
#
#        Intake Condition_TREATABLE  Intake Condition_UNTREATABLE
# 9                               0                             0
# 24                              0                             0
# 25                              0                             0
# 40                              0                             0
# 43                              0                             0
# ...                           ...                           ...
# 25426                           0                             0
# 25427                           0                             0
# 25430                           0                             0
# 25432                           0                             1
# 25433                           0                             0
#
# [10588 rows x 398 columns]

# %%
decision
# Out:
# 9         4.0
# 24       45.0
# 25       33.0
# 40        1.0
# 43        1.0
#          ...
# 25426    16.0
# 25427     5.0
# 25430    20.0
# 25432    21.0
# 25433    49.0
# Name: Days in Shelter, Length: 10588, dtype: float64

# %%
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()
# decision = scaler.fit_transform(decision)

# %%
from sklearn.model_selection import train_test_split

# decision = df["Days in Shelter"]
# attributes = df.drop("Days in Shelter", axis=1)

X_train, X_test, y_train, y_test = train_test_split(attributes, decision, test_size=0.25)

# %%
def graph_for_model(y_test, y_pred, model_name):
    plt.figure(figsize=(8, 8))
    plt.scatter(y_test, y_pred, c='b', marker='o', label='Actual vs. Predicted')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title('MODEL - {model_name}'.format(model_name=model_name))
    plt.legend(loc='upper left')
    plt.grid(True)

    plt.show()

# %% [markdown]
# Random forest

# %%
# send_message_to_telegram("Starting training")

# %%
# from sklearn.linear_model import LinearRegression
# from sklearn.metrics import r2_score, mean_squared_error

# model_LinearRegression = LinearRegression()
# model_LinearRegression.fit(X_train, y_train)
# y_pred_LinearRegression = model_LinearRegression.predict(X_test)
# mse_LinearRegression = mean_squared_error(y_test, y_pred_LinearRegression)
# r2_LinearRegression = r2_score(y_test, y_pred_LinearRegression)

# rounded_mse_LinearRegression = str(round(mse_LinearRegression, 3))
# rounded_r2_LinearRegression = str(round(r2_LinearRegression, 3))

# print("Mean Squared Error:", rounded_mse_LinearRegression)
# print("R^2 Score:", rounded_r2_LinearRegression)
# Out:
# Mean Squared Error: 151.086
# R^2 Score: 0.119

# %%
# graph_for_model(y_test, y_pred_LinearRegression, "Linear Regression")

# %%
# from sklearn.linear_model import Ridge, Lasso, BayesianRidge

# model_Ridge = Ridge()
# model_Ridge.fit(X_train, y_train)
# y_pred_Ridge = model_Ridge.predict(X_test)
# mse_Ridge = mean_squared_error(y_test, y_pred_Ridge)
# r2_Ridge = r2_score(y_test, y_pred_Ridge)

# rounded_mse_Ridge = str(round(mse_Ridge, 3))
# rounded_r2_Ridge = str(round(r2_Ridge, 3))

# print("Mean Squared Error:", rounded_mse_Ridge)
# print("R^2 Score:", rounded_r2_Ridge)
# Out:
# Mean Squared Error: 149.305
# R^2 Score: 0.129

# %%
# graph_for_model(y_test, y_pred_Ridge, "Ridge")

# %%
# model_Lasso = Lasso()
# model_Lasso.fit(X_train, y_train)
# y_pred_Lasso = model_Lasso.predict(X_test)
# mse_Lasso = mean_squared_error(y_test, y_pred_Lasso)
# r2_Lasso = r2_score(y_test, y_pred_Lasso)

# rounded_mse_Lasso = str(round(mse_Lasso, 3))
# rounded_r2_Lasso = str(round(r2_Lasso, 3))

# print("Mean Squared Error:", rounded_mse_Lasso)
# print("R^2 Score:", rounded_r2_Lasso)
# Out:
# Mean Squared Error: 162.082
# R^2 Score: 0.054

# %%
# graph_for_model(y_test, y_pred_Ridge, "Ridge")

# %%
# model_BayesianRidge = BayesianRidge()
# model_BayesianRidge.fit(X_train, y_train)
# y_pred_BayesianRidge = model_BayesianRidge.predict(X_test)
# mse_BayesianRidge = mean_squared_error(y_test, y_pred_BayesianRidge)
# r2_BayesianRidge = r2_score(y_test, y_pred_BayesianRidge)

# rounded_mse_BayesianRidge = str(round(mse_BayesianRidge, 3))
# rounded_r2_BayesianRidge = str(round(r2_BayesianRidge, 3))

# print("Mean Squared Error:", rounded_mse_BayesianRidge)
# print("R^2 Score:", rounded_r2_BayesianRidge)
# Out:
# Mean Squared Error: 147.393
# R^2 Score: 0.14

# %%
# graph_for_model(y_test, y_pred_BayesianRidge, "BayesianRidge")

# %%
# from sklearn.svm import SVR

# model_SVR = SVR(kernel="rbf")
# model_SVR.fit(X_train, y_train)
# y_pred_SVR = model_SVR.predict(X_test)
# mse_SVR = mean_squared_error(y_test, y_pred_SVR)
# r2_SVR = r2_score(y_test, y_pred_SVR)

# rounded_mse_SVR = str(round(mse_SVR, 3))
# rounded_r2_SVR = str(round(r2_SVR, 3))

# print("Mean Squared Error:", rounded_mse_SVR)
# print("R^2 Score:", rounded_r2_SVR)
# Out:
# Mean Squared Error: 152.851
# R^2 Score: 0.108

# %%
# graph_for_model(y_test, y_pred_SVR, "SVR")

# %%
# from sklearn.tree import DecisionTreeRegressor

# model_DecisionTreeRegressor = DecisionTreeRegressor()
# model_DecisionTreeRegressor.fit(X_train, y_train)
# y_pred_DecisionTreeRegressor = model_DecisionTreeRegressor.predict(X_test)
# mse_DecisionTreeRegressor = mean_squared_error(y_test, y_pred_DecisionTreeRegressor)
# r2_DecisionTreeRegressor = r2_score(y_test, y_pred_DecisionTreeRegressor)

# rounded_mse_DecisionTreeRegressor = str(round(mse_DecisionTreeRegressor, 3))
# rounded_r2_DecisionTreeRegressor = str(round(r2_DecisionTreeRegressor, 3))

# print("Mean Squared Error:", rounded_mse_DecisionTreeRegressor)
# print("R^2 Score:", rounded_r2_DecisionTreeRegressor)
# Out:
# Mean Squared Error: 248.588
# R^2 Score: -0.45

# %%
# graph_for_model(y_test, y_pred_DecisionTreeRegressor, "DecisionTreeRegressor")

# %% [markdown]
# NN

# %%
import tensorflow as tf
from tensorflow.keras.regularizers import l1, l2

model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(512, activation='relu', kernel_regularizer=l2(0.01), input_shape=(X_train.shape[1],)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3)
    # tf.keras.layers.Dense(256, activation='relu', kernel_regularizer=l2(0.01)),
    # tf.keras.layers.BatchNormalization(),
    # tf.keras.layers.Dropout(0.3),
    # tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=l2(0.01)),
    # tf.keras.layers.BatchNormalization(),
    # tf.keras.layers.Dropout(0.2),
    # tf.keras.layers.Dense(1)
])

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'activation': ['relu', 'swish'],
    'dropout_rate': [0.2, 0.3],
    'kernel_regularizer': [l1(0.01), l2(0.01)]
}

grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=3)
grid_result = grid_search.fit(X_train, y_train)

print("Najlepsze hiperparametry:", grid_result.best_params_)

# %%
model.compile(optimizer='adam',
              metrics=['mean_squared_error'],
              loss='mean_absolute_error')

# %%
model.summary()

# %%
import matplotlib.pyplot as plt

epochs = 100

history = model.fit(X_train, y_train, epochs=epochs, validation_data=(X_test, y_test))

train_loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, epochs + 1)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, train_loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, history.history['mean_squared_error'], label='Training MSE')
plt.plot(epochs_range, history.history['val_mean_squared_error'], label='Validation MSE')
plt.legend(loc='upper right')
plt.title('Training and Validation MSE')
plt.xlabel('Epochs')
plt.ylabel('MSE')

plt.show()

# %%
y_pred = model.predict(X_test)

y_pred

# %%
y_pred = y_pred.flatten()
y_pred

# %%
df_pred = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred.flatten()})
print(df_pred.to_string(index=False))

# %%
plt.figure(figsize=(8, 8))
plt.scatter(y_test, y_pred, c='b', marker='o', label='Actual vs. Predicted')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs. Predicted Values')
plt.legend(loc='upper left')
plt.grid(True)

plt.show()

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

rounded_mse = str(round(mse, 3))
rounded_r2 = str(round(r2, 3))

print("Mean Squared Error:", rounded_mse)
print("R^2 Score:", rounded_r2)

# %%
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor

def create_model(activation='relu', dropout_rate=0.3, kernel_regularizer=l2(0.01)):
    model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(512, activation=activation, kernel_regularizer=kernel_regularizer, input_shape=(X_train.shape[1],)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate),
        tf.keras.layers.Dense(256, activation=activation, kernel_regularizer=kernel_regularizer),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate),
        tf.keras.layers.Dense(128, activation=activation, kernel_regularizer=kernel_regularizer),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate),
        tf.keras.layers.Dense(1)
    ])
    model.compile(optimizer='adam', loss='mean_absolute_error', metrics=['mean_squared_error'])
    return model

model = KerasRegressor(build_fn=create_model, verbose=0)

param_grid = {
    'activation': ['relu', 'swish'],
    'dropout_rate': [0.2, 0.3],
    'kernel_regularizer': [l1(0.01), l2(0.01)]
}

grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=3)
grid_result = grid_search.fit(X_train, y_train)

print("Najlepsze hiperparametry:", grid_result.best_params_)

# %%
#Remove all files from test_data folder
import os

folder_path = "./test_data"

for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    try:
        if os.path.isfile(file_path):
            os.remove(file_path)
            print(f"Usunięto plik: {filename}")
    except Exception as e:
        print(f"Błąd podczas usuwania pliku {filename}: {e}")
